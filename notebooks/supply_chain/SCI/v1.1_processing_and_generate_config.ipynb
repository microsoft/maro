# %%
import os
import pandas as pd
import numpy as np

src_dir = "/home/Jinyu/maro/maro/simulator/scenarios/supply_chain/topologies/SCI_1.1/data"

cfg_dir = "/home/Jinyu/maro/maro/simulator/scenarios/supply_chain/topologies/SCI_1.1"
data_dir = "/home/Jinyu/maro/maro/simulator/scenarios/supply_chain/topologies/SCI_1.1"

# %%
# Valid date range: ['2011-01-29', '2016-05-22']
start_date = "2012-01-01"
end_date = "2012-12-31"

# %% [markdown]
# # Raw Data

# %% [markdown]
# ## Item -- SKU -- 83 Hobbies + 417 (Foods + household) + 1822 Components

# %%
df_item = pd.read_parquet(os.path.join(src_dir, "item.parquet"))
df_item.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2682 entries, 0 to 2321
# Data columns (total 5 columns):
# ItemId                    2682 non-null object
# ItemName                  2682 non-null object
# ProductId                 566 non-null object
# IsItemTypeFinishedGood    2682 non-null bool
# VendorId                  2599 non-null object
# dtypes: bool(1), object(4)
# memory usage: 107.4+ KB

# %%
df_item.head(5)
# Out:
#             ItemId         ItemName        ProductId  IsItemTypeFinishedGood  \
# 0      FOODS_3_535      FOODS_3_535      FOODS_3_535                    True
# 1      FOODS_2_307      FOODS_2_307      FOODS_2_307                    True
# 1      FOODS_2_307      FOODS_2_307      FOODS_2_307                    True
# 2    HOBBIES_1_317    HOBBIES_1_317    HOBBIES_1_317                    True
# 3  HOUSEHOLD_1_467  HOUSEHOLD_1_467  HOUSEHOLD_1_467                    True
#
#   VendorId
# 0  VNDR_28
# 1   VNDR_6
# 1  VNDR_24
# 2     None
# 3   VNDR_5

# %%
df_item = df_item.drop_duplicates().reset_index(drop=True)
df_item
# Out:
#                ItemId         ItemName        ProductId  \
# 0         FOODS_3_535      FOODS_3_535      FOODS_3_535
# 1         FOODS_2_307      FOODS_2_307      FOODS_2_307
# 2         FOODS_2_307      FOODS_2_307      FOODS_2_307
# 3       HOBBIES_1_317    HOBBIES_1_317    HOBBIES_1_317
# 4     HOUSEHOLD_1_467  HOUSEHOLD_1_467  HOUSEHOLD_1_467
# ...               ...              ...              ...
# 2677        COMP_1270        COMP_1270             None
# 2678         COMP_763         COMP_763             None
# 2679        COMP_1661        COMP_1661             None
# 2680         COMP_537         COMP_537             None
# 2681        COMP_1692        COMP_1692             None
#
#       IsItemTypeFinishedGood VendorId
# 0                       True  VNDR_28
# 1                       True   VNDR_6
# 2                       True  VNDR_24
# 3                       True     None
# 4                       True   VNDR_5
# ...                      ...      ...
# 2677                   False  VNDR_20
# 2678                   False   VNDR_2
# 2679                   False  VNDR_10
# 2680                   False   VNDR_8
# 2681                   False  VNDR_10
#
# [2682 rows x 5 columns]

# %%
df_item[df_item["VendorId"].isnull()]
# Out:
#             ItemId       ItemName      ProductId  IsItemTypeFinishedGood  \
# 3    HOBBIES_1_317  HOBBIES_1_317  HOBBIES_1_317                    True
# 6    HOBBIES_1_003  HOBBIES_1_003  HOBBIES_1_003                    True
# 13   HOBBIES_1_400  HOBBIES_1_400  HOBBIES_1_400                    True
# 17   HOBBIES_2_143  HOBBIES_2_143  HOBBIES_2_143                    True
# 18   HOBBIES_1_069  HOBBIES_1_069  HOBBIES_1_069                    True
# ..             ...            ...            ...                     ...
# 512  HOBBIES_1_357  HOBBIES_1_357  HOBBIES_1_357                    True
# 550  HOBBIES_2_103  HOBBIES_2_103  HOBBIES_2_103                    True
# 553  HOBBIES_2_119  HOBBIES_2_119  HOBBIES_2_119                    True
# 557  HOBBIES_1_045  HOBBIES_1_045  HOBBIES_1_045                    True
# 565  HOBBIES_1_072  HOBBIES_1_072  HOBBIES_1_072                    True
#
#     VendorId
# 3       None
# 6       None
# 13      None
# 17      None
# 18      None
# ..       ...
# 512     None
# 550     None
# 553     None
# 557     None
# 565     None
#
# [83 rows x 5 columns]

# %%
product_item = df_item[~df_item["ProductId"].isnull()]
product_item
# Out:
#               ItemId         ItemName        ProductId  \
# 0        FOODS_3_535      FOODS_3_535      FOODS_3_535
# 1        FOODS_2_307      FOODS_2_307      FOODS_2_307
# 2        FOODS_2_307      FOODS_2_307      FOODS_2_307
# 3      HOBBIES_1_317    HOBBIES_1_317    HOBBIES_1_317
# 4    HOUSEHOLD_1_467  HOUSEHOLD_1_467  HOUSEHOLD_1_467
# ..               ...              ...              ...
# 561  HOUSEHOLD_1_067  HOUSEHOLD_1_067  HOUSEHOLD_1_067
# 562  HOUSEHOLD_1_067  HOUSEHOLD_1_067  HOUSEHOLD_1_067
# 563      FOODS_3_084      FOODS_3_084      FOODS_3_084
# 564      FOODS_3_626      FOODS_3_626      FOODS_3_626
# 565    HOBBIES_1_072    HOBBIES_1_072    HOBBIES_1_072
#
#      IsItemTypeFinishedGood VendorId
# 0                      True  VNDR_28
# 1                      True   VNDR_6
# 2                      True  VNDR_24
# 3                      True     None
# 4                      True   VNDR_5
# ..                      ...      ...
# 561                    True  VNDR_14
# 562                    True  VNDR_28
# 563                    True  VNDR_10
# 564                    True  VNDR_25
# 565                    True     None
#
# [566 rows x 5 columns]

# %%
all(product_item.apply(lambda r: r["ItemId"] == r["ProductId"], axis=1))
# Out:
# True

# %%
all(df_item.apply(lambda r: r["ItemId"] == r["ItemName"], axis=1))
# Out:
# True

# %%
# Based on the checkings above
df_item = df_item.drop(columns=["ItemName", "ProductId"])
df_item
# Out:
#                ItemId  IsItemTypeFinishedGood VendorId
# 0         FOODS_3_535                    True  VNDR_28
# 1         FOODS_2_307                    True   VNDR_6
# 2         FOODS_2_307                    True  VNDR_24
# 3       HOBBIES_1_317                    True     None
# 4     HOUSEHOLD_1_467                    True   VNDR_5
# ...               ...                     ...      ...
# 2677        COMP_1270                   False  VNDR_20
# 2678         COMP_763                   False   VNDR_2
# 2679        COMP_1661                   False  VNDR_10
# 2680         COMP_537                   False   VNDR_8
# 2681        COMP_1692                   False  VNDR_10
#
# [2682 rows x 3 columns]

# %%
df_item["ItemId"].nunique()
# Out:
# 2322

# %%
df_item[df_item["IsItemTypeFinishedGood"]==True]["ItemId"].nunique()
# Out:
# 500

# %%
df_item[df_item["VendorId"].isnull()]["ItemId"].nunique()
# Out:
# 83

# %% [markdown]
# ### Items From Vendor

# %%
df_from_vendor = df_item[~df_item["VendorId"].isnull()]
df_from_vendor
# Out:
#                ItemId  IsItemTypeFinishedGood VendorId
# 0         FOODS_3_535                    True  VNDR_28
# 1         FOODS_2_307                    True   VNDR_6
# 2         FOODS_2_307                    True  VNDR_24
# 4     HOUSEHOLD_1_467                    True   VNDR_5
# 5         FOODS_2_135                    True   VNDR_7
# ...               ...                     ...      ...
# 2677        COMP_1270                   False  VNDR_20
# 2678         COMP_763                   False   VNDR_2
# 2679        COMP_1661                   False  VNDR_10
# 2680         COMP_537                   False   VNDR_8
# 2681        COMP_1692                   False  VNDR_10
#
# [2599 rows x 3 columns]

# %%
df_from_vendor["ItemId"].nunique()
# Out:
# 2239

# %% [markdown]
# ## BOM

# %%
df_bom = pd.read_parquet(os.path.join(src_dir, "billofmateriallines.parquet"))
df_bom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12076 entries, 0 to 12075
# Data columns (total 6 columns):
# BillofMaterialLineId    12076 non-null object
# ProductId               12076 non-null object
# ItemId                  12076 non-null object
# ComponentItemId         12076 non-null object
# UnitOfMeasureId         12076 non-null object
# ComponentQuantity       12076 non-null int64
# dtypes: int64(1), object(5)
# memory usage: 660.4+ KB

# %%
df_bom = df_bom.drop_duplicates().reset_index(drop=True)
df_bom.head(5)
# Out:
#   BillofMaterialLineId      ProductId         ItemId ComponentItemId  \
# 0                BOM_0  HOBBIES_1_317  HOBBIES_1_317        COMP_758
# 1                BOM_1  HOBBIES_1_317  HOBBIES_1_317       COMP_1112
# 2                BOM_2  HOBBIES_1_317  HOBBIES_1_317       COMP_1965
# 3                BOM_3  HOBBIES_1_317  HOBBIES_1_317       COMP_1202
# 4                BOM_4  HOBBIES_1_317  HOBBIES_1_317         COMP_99
#
#   UnitOfMeasureId  ComponentQuantity
# 0              PC                  7
# 1              PC                  5
# 2              PC                  9
# 3              PC                  6
# 4              PC                  3

# %%
df_bom["UnitOfMeasureId"].value_counts()
# Out:
# PC    12076
# Name: UnitOfMeasureId, dtype: int64

# %%
len(df_bom["BillofMaterialLineId"].value_counts())
# Out:
# 12076

# %%
all(product_item.apply(lambda r: r["ItemId"] == r["ProductId"], axis=1))
# Out:
# True

# %%
len(df_bom["ItemId"].value_counts())
# Out:
# 83

# %%
df_bom = df_bom.drop(columns=["BillofMaterialLineId", "ProductId", "UnitOfMeasureId"])
df_bom
# Out:
#               ItemId ComponentItemId  ComponentQuantity
# 0      HOBBIES_1_317        COMP_758                  7
# 1      HOBBIES_1_317       COMP_1112                  5
# 2      HOBBIES_1_317       COMP_1965                  9
# 3      HOBBIES_1_317       COMP_1202                  6
# 4      HOBBIES_1_317         COMP_99                  3
# ...              ...             ...                ...
# 12071  HOBBIES_1_072       COMP_1113                  6
# 12072  HOBBIES_1_072       COMP_1771                  8
# 12073  HOBBIES_1_072       COMP_1307                  8
# 12074  HOBBIES_1_072       COMP_2000                  1
# 12075  HOBBIES_1_072       COMP_1973                 12
#
# [12076 rows x 3 columns]

# %%
df_bom = df_bom[df_bom["ComponentQuantity"] > 0]
df_bom
# Out:
#               ItemId ComponentItemId  ComponentQuantity
# 0      HOBBIES_1_317        COMP_758                  7
# 1      HOBBIES_1_317       COMP_1112                  5
# 2      HOBBIES_1_317       COMP_1965                  9
# 3      HOBBIES_1_317       COMP_1202                  6
# 4      HOBBIES_1_317         COMP_99                  3
# ...              ...             ...                ...
# 12071  HOBBIES_1_072       COMP_1113                  6
# 12072  HOBBIES_1_072       COMP_1771                  8
# 12073  HOBBIES_1_072       COMP_1307                  8
# 12074  HOBBIES_1_072       COMP_2000                  1
# 12075  HOBBIES_1_072       COMP_1973                 12
#
# [12076 rows x 3 columns]

# %% [markdown]
# ## Warehouse -- Facilities

# %%
df_facility = pd.read_parquet(os.path.join(src_dir, "warehouse.parquet"))
df_facility.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15 entries, 0 to 14
# Data columns (total 6 columns):
# WarehouseId             15 non-null object
# AddressState            15 non-null object
# AddressCity             15 non-null object
# AddressCountryRegion    15 non-null object
# AddressPostalCode       15 non-null int64
# StorageCapacity         15 non-null float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 840.0+ bytes

# %%
df_facility = df_facility.drop_duplicates().reset_index(drop=True)
df_facility
# Out:
#    WarehouseId AddressState    AddressCity AddressCountryRegion  \
# 0         CA_1           CA     Sacramento                   US
# 1         CA_2           CA  San Francisco                   US
# 2         CA_3           CA    Los Angeles                   US
# 3         CA_4           CA      San Diego                   US
# 4         TX_1           TX         Dallas                   US
# 5         TX_2           TX     Fort Worth                   US
# 6         TX_3           TX         Austin                   US
# 7         WI_1           WI        Madison                   US
# 8         WI_2           WI      Milwaukee                   US
# 9         WI_3           WI      Sheboygan                   US
# 10  PLANT_WH_0           CA          Chico                   US
# 11  PLANT_WH_1           CA          Chico                   US
# 12   STRG_CA_1           CA     Sacramento                   US
# 13   STRG_TX_1           TX         Dallas                   US
# 14   STRG_WI_1           WI        Madison                   US
#
#     AddressPostalCode  StorageCapacity
# 0               72866         13288.32
# 1               92294         12235.17
# 2               64759         17099.18
# 3               85027          9417.19
# 4               37183         11358.55
# 5               21420         12820.32
# 6               39172         11917.58
# 7               27416         11052.82
# 8               83644         13520.24
# 9               64104         12506.00
# 10              11111      14522885.36
# 11              11111      14522885.36
# 12              72866         52039.86
# 13              37183         36096.45
# 14              27416         37079.06

# %%
df_facility = df_facility.drop(columns=["AddressState", "AddressCity", "AddressCountryRegion", "AddressPostalCode"])
df_facility
# Out:
#    WarehouseId  StorageCapacity
# 0         CA_1         13288.32
# 1         CA_2         12235.17
# 2         CA_3         17099.18
# 3         CA_4          9417.19
# 4         TX_1         11358.55
# 5         TX_2         12820.32
# 6         TX_3         11917.58
# 7         WI_1         11052.82
# 8         WI_2         13520.24
# 9         WI_3         12506.00
# 10  PLANT_WH_0      14522885.36
# 11  PLANT_WH_1      14522885.36
# 12   STRG_CA_1         52039.86
# 13   STRG_TX_1         36096.45
# 14   STRG_WI_1         37079.06

# %%
# TODO: Vendors are not included

# %% [markdown]
# ## Production Plant -- Plant

# %%
df_plant = pd.read_parquet(os.path.join(src_dir, "production_plant.parquet"))
df_plant.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 7 columns):
# ProductionPlantId         2 non-null object
# RawMaterialWarehouseId    2 non-null object
# OutputWarehouseId         2 non-null object
# AddressState              2 non-null object
# AddressCity               2 non-null object
# AddressCountryRegion      2 non-null object
# AddressPostalCode         2 non-null int64
# dtypes: int64(1), object(6)
# memory usage: 240.0+ bytes

# %%
df_plant
# Out:
#   ProductionPlantId RawMaterialWarehouseId OutputWarehouseId AddressState  \
# 0           PLANT_0             PLANT_WH_0        PLANT_WH_0           CA
# 1           PLANT_1             PLANT_WH_1        PLANT_WH_1           CA
#
#   AddressCity AddressCountryRegion  AddressPostalCode
# 0       Chico                   US              11111
# 1       Chico                   US              11111

# %%
all(df_plant.apply(lambda r: r["RawMaterialWarehouseId"] == r["OutputWarehouseId"], axis=1))
# Out:
# True

# %%
df_plant["WarehouseId"] = df_plant["RawMaterialWarehouseId"]
df_plant
# Out:
#   ProductionPlantId RawMaterialWarehouseId OutputWarehouseId AddressState  \
# 0           PLANT_0             PLANT_WH_0        PLANT_WH_0           CA
# 1           PLANT_1             PLANT_WH_1        PLANT_WH_1           CA
#
#   AddressCity AddressCountryRegion  AddressPostalCode WarehouseId
# 0       Chico                   US              11111  PLANT_WH_0
# 1       Chico                   US              11111  PLANT_WH_1

# %%
(df_plant["WarehouseId"].isin(df_facility["WarehouseId"])).value_counts()
# Out:
# True    2
# Name: WarehouseId, dtype: int64

# %%
df_plant = df_plant.drop(columns=[
    "RawMaterialWarehouseId", "OutputWarehouseId", "AddressState", "AddressCity", "AddressCountryRegion", "AddressPostalCode"
])
df_plant
# Out:
#   ProductionPlantId WarehouseId
# 0           PLANT_0  PLANT_WH_0
# 1           PLANT_1  PLANT_WH_1

# %% [markdown]
# ## Storage Assignment -- SKU Price + Storage Unit Cost

# %%
df_sku_info = pd.read_parquet(os.path.join(src_dir, "storage_assignment.parquet"))
df_sku_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9723 entries, 0 to 9722
# Data columns (total 6 columns):
# ItemId               9723 non-null object
# WarehouseId          9723 non-null object
# UnitPrice            9723 non-null float64
# StorageCost          9723 non-null float64
# UnitOfStorageCost    9723 non-null object
# InventoryOnHand      9723 non-null float64
# dtypes: float64(3), object(3)
# memory usage: 531.7+ KB

# %%
df_sku_info = df_sku_info.drop_duplicates().reset_index(drop=True)
df_sku_info
# Out:
#            ItemId WarehouseId  UnitPrice  StorageCost UnitOfStorageCost  \
# 0        COMP_758  PLANT_WH_0       1.18      0.00064             daily
# 1       COMP_1112  PLANT_WH_0       0.94      0.00046             daily
# 2       COMP_1965  PLANT_WH_0       0.65      0.00022             daily
# 3       COMP_1202  PLANT_WH_0       0.40      0.00022             daily
# 4         COMP_99  PLANT_WH_0       2.14      0.00068             daily
# ...           ...         ...        ...          ...               ...
# 9718  FOODS_3_822        TX_2       3.81      0.00248             daily
# 9719  FOODS_3_822        TX_3       3.80      0.00131             daily
# 9720  FOODS_3_822        WI_1       3.94      0.00172             daily
# 9721  FOODS_3_822        WI_2       3.95      0.00238             daily
# 9722  FOODS_3_822        WI_3       3.91      0.00207             daily
#
#       InventoryOnHand
# 0              540.22
# 1             6388.35
# 2             1581.49
# 3             3972.47
# 4             4068.85
# ...               ...
# 9718            17.64
# 9719            19.05
# 9720            14.60
# 9721            27.89
# 9722            21.10
#
# [9723 rows x 6 columns]

# %%
df_sku_info.head(5)
# Out:
#       ItemId WarehouseId  UnitPrice  StorageCost UnitOfStorageCost  \
# 0   COMP_758  PLANT_WH_0       1.18      0.00064             daily
# 1  COMP_1112  PLANT_WH_0       0.94      0.00046             daily
# 2  COMP_1965  PLANT_WH_0       0.65      0.00022             daily
# 3  COMP_1202  PLANT_WH_0       0.40      0.00022             daily
# 4    COMP_99  PLANT_WH_0       2.14      0.00068             daily
#
#    InventoryOnHand
# 0           540.22
# 1          6388.35
# 2          1581.49
# 3          3972.47
# 4          4068.85

# %%
df_sku_info["ItemId"].nunique() == df_item["ItemId"].nunique(), df_sku_info["ItemId"].nunique()
# Out:
# (True, 2322)

# %%
df_sku_info[df_sku_info["UnitPrice"].isnull()]["ItemId"].nunique()
# Out:
# 0

# %%
df_sku_info[df_sku_info["UnitPrice"].isnull()]
# Out:
# Empty DataFrame
# Columns: [ItemId, WarehouseId, UnitPrice, StorageCost, UnitOfStorageCost, InventoryOnHand]
# Index: []

# %%
df_sku_info[df_sku_info["UnitPrice"].isnull()]["WarehouseId"].unique()
# Out:
# array([], dtype=object)

# %%
df_sku_info[~df_sku_info["UnitPrice"].isnull()]["ItemId"].nunique()
# Out:
# 2322

# %%
df_sku_info[~df_sku_info["UnitPrice"].isnull()]["WarehouseId"].unique()
# Out:
# array(['PLANT_WH_0', 'PLANT_WH_1', 'STRG_CA_1', 'STRG_TX_1', 'STRG_WI_1',
#        'CA_1', 'CA_2', 'CA_3', 'CA_4', 'TX_1', 'TX_2', 'TX_3', 'WI_1',
#        'WI_2', 'WI_3'], dtype=object)

# %%
for item_id, group in df_sku_info.groupby(by=["ItemId"]):
    if "HOBBI" in item_id:
        break
group
# Out:
#              ItemId WarehouseId  UnitPrice  StorageCost UnitOfStorageCost  \
# 3141  HOBBIES_1_003  PLANT_WH_1    2312.39      1.16226             daily
# 3223  HOBBIES_1_003   STRG_CA_1    2312.39      1.55854             daily
# 3224  HOBBIES_1_003   STRG_TX_1    2312.39      1.07247             daily
# 3225  HOBBIES_1_003   STRG_WI_1    2312.39      1.44259             daily
# 4723  HOBBIES_1_003        CA_1    3669.62      1.98564             daily
# 4724  HOBBIES_1_003        CA_2    3531.83      1.57418             daily
# 4725  HOBBIES_1_003        CA_3    3664.79      1.14977             daily
# 4726  HOBBIES_1_003        CA_4    3652.66      1.86943             daily
# 4727  HOBBIES_1_003        TX_1    3633.32      1.70852             daily
# 4728  HOBBIES_1_003        TX_2    3532.91      1.50530             daily
# 4729  HOBBIES_1_003        TX_3    3619.73      1.44031             daily
# 4730  HOBBIES_1_003        WI_1    3633.73      2.00321             daily
# 4731  HOBBIES_1_003        WI_2    3650.46      1.45658             daily
# 4732  HOBBIES_1_003        WI_3    3622.11      1.94645             daily
#
#       InventoryOnHand
# 3141            24.15
# 3223            25.01
# 3224            17.61
# 3225            17.75
# 4723             6.75
# 4724             6.29
# 4725             6.12
# 4726             5.85
# 4727             5.99
# 4728             5.43
# 4729             6.20
# 4730             6.09
# 4731             5.54
# 4732             6.11

# %%
for item_id, group in df_sku_info.groupby(by=["ItemId"]):
    if "HOUSEHOLD" in item_id:
        break
group
# Out:
#                ItemId WarehouseId  UnitPrice  StorageCost UnitOfStorageCost  \
# 3472  HOUSEHOLD_1_001   STRG_CA_1       3.92      0.00234             daily
# 3473  HOUSEHOLD_1_001   STRG_TX_1       3.92      0.00164             daily
# 3474  HOUSEHOLD_1_001   STRG_WI_1       3.92      0.00167             daily
# 5553  HOUSEHOLD_1_001        CA_1       6.10      0.00413             daily
# 5554  HOUSEHOLD_1_001        CA_2       6.29      0.00218             daily
# 5555  HOUSEHOLD_1_001        CA_3       6.11      0.00416             daily
# 5556  HOUSEHOLD_1_001        CA_4       6.12      0.00378             daily
# 5557  HOUSEHOLD_1_001        TX_1       6.08      0.00198             daily
# 5558  HOUSEHOLD_1_001        TX_2       6.11      0.00333             daily
# 5559  HOUSEHOLD_1_001        TX_3       6.28      0.00312             daily
# 5560  HOUSEHOLD_1_001        WI_1       6.09      0.00227             daily
# 5561  HOUSEHOLD_1_001        WI_2       6.13      0.00240             daily
# 5562  HOUSEHOLD_1_001        WI_3       6.19      0.00172             daily
#
#       InventoryOnHand
# 3472            28.41
# 3473            17.52
# 3474            20.25
# 5553             6.44
# 5554             7.59
# 5555             7.91
# 5556             6.46
# 5557             5.69
# 5558             6.12
# 5559             5.71
# 5560             7.78
# 5561             6.74
# 5562             5.73

# %%
for item_id, group in df_sku_info.groupby(by=["ItemId"]):
    if "FOOD" in item_id:
        break
group
# Out:
#            ItemId WarehouseId  UnitPrice  StorageCost UnitOfStorageCost  \
# 3949  FOODS_1_002   STRG_CA_1       5.23      0.00212             daily
# 3950  FOODS_1_002   STRG_TX_1       5.23      0.00340             daily
# 3951  FOODS_1_002   STRG_WI_1       5.23      0.00307             daily
# 7143  FOODS_1_002        CA_1       8.87      0.00489             daily
# 7144  FOODS_1_002        CA_2       9.03      0.00592             daily
# 7145  FOODS_1_002        CA_3       8.90      0.00387             daily
# 7146  FOODS_1_002        CA_4       8.90      0.00513             daily
# 7147  FOODS_1_002        TX_1       8.87      0.00557             daily
# 7148  FOODS_1_002        TX_2       8.88      0.00560             daily
# 7149  FOODS_1_002        TX_3       8.89      0.00449             daily
# 7150  FOODS_1_002        WI_1       9.00      0.00553             daily
# 7151  FOODS_1_002        WI_2       9.03      0.00475             daily
# 7152  FOODS_1_002        WI_3       8.80      0.00419             daily
#
#       InventoryOnHand
# 3949            28.36
# 3950            19.29
# 3951            22.02
# 7143             7.18
# 7144             8.18
# 7145             6.65
# 7146             6.34
# 7147             6.59
# 7148             5.98
# 7149             6.72
# 7150             8.30
# 7151             6.73
# 7152             6.98

# %%
for item_id, group in df_sku_info.groupby(by=["ItemId"]):
    if "COMP" in item_id and group.shape[0] > 1:
        break
group
# Out:
#       ItemId WarehouseId  UnitPrice  StorageCost UnitOfStorageCost  \
# 139   COMP_1  PLANT_WH_1        0.8      0.00046             daily
# 1836  COMP_1  PLANT_WH_0        0.8      0.00041             daily
#
#       InventoryOnHand
# 139           2320.28
# 1836          2320.28

# %%
df_sku_info = df_sku_info.drop(columns=["UnitOfStorageCost"])
df_sku_info
# Out:
#            ItemId WarehouseId  UnitPrice  StorageCost  InventoryOnHand
# 0        COMP_758  PLANT_WH_0       1.18      0.00064           540.22
# 1       COMP_1112  PLANT_WH_0       0.94      0.00046          6388.35
# 2       COMP_1965  PLANT_WH_0       0.65      0.00022          1581.49
# 3       COMP_1202  PLANT_WH_0       0.40      0.00022          3972.47
# 4         COMP_99  PLANT_WH_0       2.14      0.00068          4068.85
# ...           ...         ...        ...          ...              ...
# 9718  FOODS_3_822        TX_2       3.81      0.00248            17.64
# 9719  FOODS_3_822        TX_3       3.80      0.00131            19.05
# 9720  FOODS_3_822        WI_1       3.94      0.00172            14.60
# 9721  FOODS_3_822        WI_2       3.95      0.00238            27.89
# 9722  FOODS_3_822        WI_3       3.91      0.00207            21.10
#
# [9723 rows x 5 columns]

# %% [markdown]
# ## Production Assignment -- Manufacture Info

# %%
df_manufacture_info = pd.read_parquet(os.path.join(src_dir, "production_assignment.parquet"))
df_manufacture_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 83 entries, 0 to 82
# Data columns (total 8 columns):
# ItemId                    83 non-null object
# ProductionPlantId         83 non-null object
# ProductionAssignmentId    83 non-null object
# ManufactureLeadTime       83 non-null int64
# ManufactureRate           83 non-null float64
# UnitMaterialCost          83 non-null float64
# UnitManufactureCost       83 non-null float64
# UnitPrice                 83 non-null float64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 5.8+ KB

# %%
df_manufacture_info = df_manufacture_info.drop_duplicates().reset_index(drop=True)
df_manufacture_info
# Out:
#            ItemId ProductionPlantId ProductionAssignmentId  \
# 0   HOBBIES_1_317           PLANT_0           ProdAssign_0
# 1   HOBBIES_1_003           PLANT_1           ProdAssign_1
# 2   HOBBIES_1_400           PLANT_1           ProdAssign_2
# 3   HOBBIES_2_143           PLANT_0           ProdAssign_3
# 4   HOBBIES_1_069           PLANT_0           ProdAssign_4
# ..            ...               ...                    ...
# 78  HOBBIES_1_357           PLANT_1          ProdAssign_78
# 79  HOBBIES_2_103           PLANT_0          ProdAssign_79
# 80  HOBBIES_2_119           PLANT_0          ProdAssign_80
# 81  HOBBIES_1_045           PLANT_1          ProdAssign_81
# 82  HOBBIES_1_072           PLANT_1          ProdAssign_82
#
#     ManufactureLeadTime  ManufactureRate  UnitMaterialCost  \
# 0                     2            20.40            274.29
# 1                     4            18.11           1063.04
# 2                     1            50.28             21.95
# 3                     1            30.66             22.06
# 4                     5            17.57            279.38
# ..                  ...              ...               ...
# 78                    5            21.47            449.00
# 79                    5            19.98            553.33
# 80                    1            15.39           1304.19
# 81                    3            18.13           3403.99
# 82                    3            22.39            825.20
#
#     UnitManufactureCost  UnitPrice
# 0                 40.13     314.42
# 1               1249.35    2312.39
# 2                 42.63      64.58
# 3                 14.70      36.76
# 4                262.09     541.47
# ..                  ...        ...
# 78               797.32    1246.32
# 79               600.42    1153.75
# 80              2476.93    3781.12
# 81              3213.75    6617.74
# 82               144.44     969.64
#
# [83 rows x 8 columns]

# %%
df_manufacture_info[~df_manufacture_info["UnitPrice"].isnull()]
# Out:
#            ItemId ProductionPlantId ProductionAssignmentId  \
# 0   HOBBIES_1_317           PLANT_0           ProdAssign_0
# 1   HOBBIES_1_003           PLANT_1           ProdAssign_1
# 2   HOBBIES_1_400           PLANT_1           ProdAssign_2
# 3   HOBBIES_2_143           PLANT_0           ProdAssign_3
# 4   HOBBIES_1_069           PLANT_0           ProdAssign_4
# ..            ...               ...                    ...
# 78  HOBBIES_1_357           PLANT_1          ProdAssign_78
# 79  HOBBIES_2_103           PLANT_0          ProdAssign_79
# 80  HOBBIES_2_119           PLANT_0          ProdAssign_80
# 81  HOBBIES_1_045           PLANT_1          ProdAssign_81
# 82  HOBBIES_1_072           PLANT_1          ProdAssign_82
#
#     ManufactureLeadTime  ManufactureRate  UnitMaterialCost  \
# 0                     2            20.40            274.29
# 1                     4            18.11           1063.04
# 2                     1            50.28             21.95
# 3                     1            30.66             22.06
# 4                     5            17.57            279.38
# ..                  ...              ...               ...
# 78                    5            21.47            449.00
# 79                    5            19.98            553.33
# 80                    1            15.39           1304.19
# 81                    3            18.13           3403.99
# 82                    3            22.39            825.20
#
#     UnitManufactureCost  UnitPrice
# 0                 40.13     314.42
# 1               1249.35    2312.39
# 2                 42.63      64.58
# 3                 14.70      36.76
# 4                262.09     541.47
# ..                  ...        ...
# 78               797.32    1246.32
# 79               600.42    1153.75
# 80              2476.93    3781.12
# 81              3213.75    6617.74
# 82               144.44     969.64
#
# [83 rows x 8 columns]

# %%
df_manufacture_info = df_manufacture_info.merge(df_plant, on="ProductionPlantId")
df_manufacture_info
# Out:
#            ItemId ProductionPlantId ProductionAssignmentId  \
# 0   HOBBIES_1_317           PLANT_0           ProdAssign_0
# 1   HOBBIES_2_143           PLANT_0           ProdAssign_3
# 2   HOBBIES_1_069           PLANT_0           ProdAssign_4
# 3   HOBBIES_1_366           PLANT_0           ProdAssign_5
# 4   HOBBIES_1_017           PLANT_0           ProdAssign_6
# ..            ...               ...                    ...
# 78  HOBBIES_1_405           PLANT_1          ProdAssign_72
# 79  HOBBIES_1_044           PLANT_1          ProdAssign_74
# 80  HOBBIES_1_357           PLANT_1          ProdAssign_78
# 81  HOBBIES_1_045           PLANT_1          ProdAssign_81
# 82  HOBBIES_1_072           PLANT_1          ProdAssign_82
#
#     ManufactureLeadTime  ManufactureRate  UnitMaterialCost  \
# 0                     2            20.40            274.29
# 1                     1            30.66             22.06
# 2                     5            17.57            279.38
# 3                     5            17.73            252.67
# 4                     5            29.96           3427.17
# ..                  ...              ...               ...
# 78                    3            17.86            728.89
# 79                    2            22.57            156.27
# 80                    5            21.47            449.00
# 81                    3            18.13           3403.99
# 82                    3            22.39            825.20
#
#     UnitManufactureCost  UnitPrice WarehouseId
# 0                 40.13     314.42  PLANT_WH_0
# 1                 14.70      36.76  PLANT_WH_0
# 2                262.09     541.47  PLANT_WH_0
# 3                354.83     607.50  PLANT_WH_0
# 4               1018.65    4445.82  PLANT_WH_0
# ..                  ...        ...         ...
# 78               967.40    1696.29  PLANT_WH_1
# 79               231.64     387.91  PLANT_WH_1
# 80               797.32    1246.32  PLANT_WH_1
# 81              3213.75    6617.74  PLANT_WH_1
# 82               144.44     969.64  PLANT_WH_1
#
# [83 rows x 9 columns]

# %%
df_merged = pd.merge(df_sku_info, df_manufacture_info, on=["ItemId", "WarehouseId"])
df_merged.head(5)
# Out:
#           ItemId WarehouseId  UnitPrice_x  StorageCost  InventoryOnHand  \
# 0  HOBBIES_1_317  PLANT_WH_0       314.42      0.13519            27.21
# 1  HOBBIES_1_003  PLANT_WH_1      2312.39      1.16226            24.15
# 2  HOBBIES_1_400  PLANT_WH_1        64.58      0.03411            67.04
# 3  HOBBIES_2_143  PLANT_WH_0        36.76      0.02358            40.89
# 4  HOBBIES_1_069  PLANT_WH_0       541.47      0.29200            23.43
#
#   ProductionPlantId ProductionAssignmentId  ManufactureLeadTime  \
# 0           PLANT_0           ProdAssign_0                    2
# 1           PLANT_1           ProdAssign_1                    4
# 2           PLANT_1           ProdAssign_2                    1
# 3           PLANT_0           ProdAssign_3                    1
# 4           PLANT_0           ProdAssign_4                    5
#
#    ManufactureRate  UnitMaterialCost  UnitManufactureCost  UnitPrice_y
# 0            20.40            274.29                40.13       314.42
# 1            18.11           1063.04              1249.35      2312.39
# 2            50.28             21.95                42.63        64.58
# 3            30.66             22.06                14.70        36.76
# 4            17.57            279.38               262.09       541.47

# %%
all(df_merged.apply(lambda r: r["UnitPrice_x"] - r["UnitPrice_y"] <= 0.01, axis=1))
# Out:
# True

# %%
for i, r in df_merged.iterrows():
    if r["UnitPrice_x"] != r["UnitPrice_y"]:
        print(r["UnitPrice_x"], r["UnitPrice_y"])
# Out:
# 918.1 918.0999999999999
# 210.83 210.82999999999998
# 17.24 17.240000000000002
# 10962.72 10962.720000000001
# 7752.44 7752.4400000000005
# 388.09 388.09000000000003
# 6099.15 6099.150000000001
# 3701.1 3701.1000000000004
# 184.4 184.39999999999998
# 496.05 496.04999999999995
# 1476.32 1476.3200000000002
# 963.41 963.4100000000001
# 458.42 458.41999999999996
# 387.91 387.90999999999997
# 823.06 823.0600000000001
# 461.04 461.03999999999996
# 1246.32 1246.3200000000002
# 969.64 969.6400000000001

# %%
all(df_merged.apply(lambda r: r["UnitPrice_x"] - r["UnitManufactureCost"] - r["UnitMaterialCost"] < 1, axis=1))
# Out:
# True

# %%
df_manufacture_info = df_manufacture_info.drop(columns=[
    "ProductionPlantId", "ProductionAssignmentId", "UnitPrice"
])
df_manufacture_info.head(5)
# Out:
#           ItemId  ManufactureLeadTime  ManufactureRate  UnitMaterialCost  \
# 0  HOBBIES_1_317                    2            20.40            274.29
# 1  HOBBIES_2_143                    1            30.66             22.06
# 2  HOBBIES_1_069                    5            17.57            279.38
# 3  HOBBIES_1_366                    5            17.73            252.67
# 4  HOBBIES_1_017                    5            29.96           3427.17
#
#    UnitManufactureCost WarehouseId
# 0                40.13  PLANT_WH_0
# 1                14.70  PLANT_WH_0
# 2               262.09  PLANT_WH_0
# 3               354.83  PLANT_WH_0
# 4              1018.65  PLANT_WH_0

# %%
df_manufacture_info['output_lot_per_cycle'] = df_manufacture_info['ManufactureLeadTime'] * df_manufacture_info['ManufactureRate']
df_manufacture_info
# Out:
#            ItemId  ManufactureLeadTime  ManufactureRate  UnitMaterialCost  \
# 0   HOBBIES_1_317                    2            20.40            274.29
# 1   HOBBIES_2_143                    1            30.66             22.06
# 2   HOBBIES_1_069                    5            17.57            279.38
# 3   HOBBIES_1_366                    5            17.73            252.67
# 4   HOBBIES_1_017                    5            29.96           3427.17
# ..            ...                  ...              ...               ...
# 78  HOBBIES_1_405                    3            17.86            728.89
# 79  HOBBIES_1_044                    2            22.57            156.27
# 80  HOBBIES_1_357                    5            21.47            449.00
# 81  HOBBIES_1_045                    3            18.13           3403.99
# 82  HOBBIES_1_072                    3            22.39            825.20
#
#     UnitManufactureCost WarehouseId  output_lot_per_cycle
# 0                 40.13  PLANT_WH_0                 40.80
# 1                 14.70  PLANT_WH_0                 30.66
# 2                262.09  PLANT_WH_0                 87.85
# 3                354.83  PLANT_WH_0                 88.65
# 4               1018.65  PLANT_WH_0                149.80
# ..                  ...         ...                   ...
# 78               967.40  PLANT_WH_1                 53.58
# 79               231.64  PLANT_WH_1                 45.14
# 80               797.32  PLANT_WH_1                107.35
# 81              3213.75  PLANT_WH_1                 54.39
# 82               144.44  PLANT_WH_1                 67.17
#
# [83 rows x 7 columns]

# %%
# Currently, UnitPrice = UnitManufactureCost + UnitMaterialCost; Consistent to the description in <<SCI_MARO_Mapping.xlsx>>
# TODO: UnitManufacutreCost -> seems like it is per output lot

# TODO: check the UnitMaterialCost, what if the a material corresponds to several upstreams(with different price)?

# TODO: Could ManufactureRate be float?

# %% [markdown]
# ## Distribution

# %%
df_distribution = pd.read_parquet(os.path.join(src_dir, "distribution_node.parquet"))
df_distribution.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15 entries, 0 to 14
# Data columns (total 4 columns):
# FacilityId              15 non-null object
# DistributionNodeId      15 non-null object
# DistributionCapacity    15 non-null float64
# OrderCost               15 non-null float64
# dtypes: float64(2), object(2)
# memory usage: 600.0+ bytes

# %%
df_distribution = df_distribution.drop_duplicates().reset_index(drop=True)
df_distribution
# Out:
#     FacilityId DistributionNodeId  DistributionCapacity  OrderCost
# 0         CA_1           DISTNO_0                   inf       1.07
# 1         CA_2           DISTNO_1                   inf       1.02
# 2         CA_3           DISTNO_2                   inf       0.84
# 3         CA_4           DISTNO_3                   inf       0.95
# 4         TX_1           DISTNO_4                   inf       0.85
# 5         TX_2           DISTNO_5                   inf       1.46
# 6         TX_3           DISTNO_6                   inf       0.81
# 7         WI_1           DISTNO_7                   inf       1.07
# 8         WI_2           DISTNO_8                   inf       0.77
# 9         WI_3           DISTNO_9                   inf       1.13
# 10  PLANT_WH_0          DISTNO_10                   inf       0.06
# 11  PLANT_WH_1          DISTNO_11                   inf       0.10
# 12   STRG_CA_1          DISTNO_12                   inf       0.09
# 13   STRG_TX_1          DISTNO_13                   inf       0.07
# 14   STRG_WI_1          DISTNO_14                   inf       0.07

# %%
df_distribution = df_distribution.drop(columns=["DistributionNodeId"])
df_distribution
# Out:
#     FacilityId  DistributionCapacity  OrderCost
# 0         CA_1                   inf       1.07
# 1         CA_2                   inf       1.02
# 2         CA_3                   inf       0.84
# 3         CA_4                   inf       0.95
# 4         TX_1                   inf       0.85
# 5         TX_2                   inf       1.46
# 6         TX_3                   inf       0.81
# 7         WI_1                   inf       1.07
# 8         WI_2                   inf       0.77
# 9         WI_3                   inf       1.13
# 10  PLANT_WH_0                   inf       0.06
# 11  PLANT_WH_1                   inf       0.10
# 12   STRG_CA_1                   inf       0.09
# 13   STRG_TX_1                   inf       0.07
# 14   STRG_WI_1                   inf       0.07

# %%
# Due to <<SCI_MARO_Mapping.xlsx>>, OrderCost means: fixed cost per order.

# TODO: Confirm the meaning of OrderCost.
# nothing to do with downstream? nothing to do with product? nothing to do with transporation days?

# %% [markdown]
# ## Order

# %%
df_order = pd.read_parquet(os.path.join(src_dir, "order.parquet"))
df_order.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3143786 entries, 0 to 3143785
# Data columns (total 6 columns):
# OrderId                       object
# OrderType                     object
# PurchaseOrderNumber           object
# OrderRequestedDeliveryDate    object
# OrderCommittedDeliveryDate    object
# OrderActualDeliveryDate       object
# dtypes: object(6)
# memory usage: 143.9+ MB

# %%
df_order = df_order.drop_duplicates().reset_index(drop=True)
df_order
# Out:
#                            OrderId OrderType        PurchaseOrderNumber  \
# 0        CA_1HOBBIES_1_00320140207     sales  CA_1HOBBIES_1_00320140207
# 1        CA_1HOBBIES_1_00320140209     sales  CA_1HOBBIES_1_00320140209
# 2        CA_1HOBBIES_1_00320140212     sales  CA_1HOBBIES_1_00320140212
# 3        CA_1HOBBIES_1_00320140214     sales  CA_1HOBBIES_1_00320140214
# 4        CA_1HOBBIES_1_00320140215     sales  CA_1HOBBIES_1_00320140215
# ...                            ...       ...                        ...
# 3143781    WI_3FOODS_3_82220160517     sales    WI_3FOODS_3_82220160517
# 3143782    WI_3FOODS_3_82220160519     sales    WI_3FOODS_3_82220160519
# 3143783    WI_3FOODS_3_82220160520     sales    WI_3FOODS_3_82220160520
# 3143784    WI_3FOODS_3_82220160521     sales    WI_3FOODS_3_82220160521
# 3143785    WI_3FOODS_3_82220160522     sales    WI_3FOODS_3_82220160522
#
#         OrderRequestedDeliveryDate OrderCommittedDeliveryDate  \
# 0                       2014-02-07                 2014-02-07
# 1                       2014-02-09                 2014-02-09
# 2                       2014-02-12                 2014-02-12
# 3                       2014-02-14                 2014-02-14
# 4                       2014-02-15                 2014-02-15
# ...                            ...                        ...
# 3143781                 2016-05-17                 2016-05-17
# 3143782                 2016-05-19                 2016-05-19
# 3143783                 2016-05-20                 2016-05-20
# 3143784                 2016-05-21                 2016-05-21
# 3143785                 2016-05-22                 2016-05-22
#
#         OrderActualDeliveryDate
# 0                    2014-02-07
# 1                    2014-02-09
# 2                    2014-02-12
# 3                    2014-02-14
# 4                    2014-02-15
# ...                         ...
# 3143781              2016-05-17
# 3143782              2016-05-19
# 3143783              2016-05-20
# 3143784              2016-05-21
# 3143785              2016-05-22
#
# [3143786 rows x 6 columns]

# %%
df_order["OrderType"].value_counts()
# Out:
# sales    3143786
# Name: OrderType, dtype: int64

# %% [markdown]
# ## OrderLine -- Seller Demand

# %%
df_orderline = pd.read_parquet(os.path.join(src_dir, "orderline.parquet"))
df_orderline.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3143786 entries, 0 to 3143785
# Data columns (total 11 columns):
# ConfirmedDeliveryDate      object
# ItemId                     object
# ItemUnitCost               float64
# OrderId                    object
# OrderLineId                object
# OrderLineQuantity          int64
# OrderLineStatus            object
# PlannedShipmentDate        object
# PurchaseOrderLineNumber    object
# RequestedDeliveryDate      object
# WarehouseId                object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 263.8+ MB

# %%
df_orderline = df_orderline.drop_duplicates().reset_index(drop=True)
df_orderline.head(5)
# Out:
#   ConfirmedDeliveryDate         ItemId  ItemUnitCost  \
# 0            2014-02-07  HOBBIES_1_003       3669.62
# 1            2014-02-09  HOBBIES_1_003       3669.62
# 2            2014-02-12  HOBBIES_1_003       3669.62
# 3            2014-02-14  HOBBIES_1_003       3669.62
# 4            2014-02-15  HOBBIES_1_003       3669.62
#
#                      OrderId                   OrderLineId  OrderLineQuantity  \
# 0  CA_1HOBBIES_1_00320140207  CA_1HOBBIES_1_00320140207_01                  3
# 1  CA_1HOBBIES_1_00320140209  CA_1HOBBIES_1_00320140209_01                  2
# 2  CA_1HOBBIES_1_00320140212  CA_1HOBBIES_1_00320140212_01                  1
# 3  CA_1HOBBIES_1_00320140214  CA_1HOBBIES_1_00320140214_01                  1
# 4  CA_1HOBBIES_1_00320140215  CA_1HOBBIES_1_00320140215_01                  1
#
#   OrderLineStatus PlannedShipmentDate       PurchaseOrderLineNumber  \
# 0       completed          2014-02-07  CA_1HOBBIES_1_00320140207_01
# 1       completed          2014-02-09  CA_1HOBBIES_1_00320140209_01
# 2       completed          2014-02-12  CA_1HOBBIES_1_00320140212_01
# 3       completed          2014-02-14  CA_1HOBBIES_1_00320140214_01
# 4       completed          2014-02-15  CA_1HOBBIES_1_00320140215_01
#
#   RequestedDeliveryDate WarehouseId
# 0            2014-02-07        CA_1
# 1            2014-02-09        CA_1
# 2            2014-02-12        CA_1
# 3            2014-02-14        CA_1
# 4            2014-02-15        CA_1

# %%
len(df_orderline["OrderId"].value_counts())
# Out:
# 3143786

# %%
len(df_orderline["OrderLineId"].value_counts())
# Out:
# 3143786

# %%
len(df_orderline["PurchaseOrderLineNumber"].value_counts())
# Out:
# 3143786

# %%
df_orderline["OrderLineStatus"].value_counts()
# Out:
# completed    3143786
# Name: OrderLineStatus, dtype: int64

# %%
df_orderline["ItemId"].nunique()
# Out:
# 500

# %%
df_orderline["WarehouseId"].nunique()
# Out:
# 10

# %%
len(df_orderline["ItemUnitCost"].value_counts())
# Out:
# 1327

# %%
df_orderline.groupby(["WarehouseId", "ItemId"])["ItemUnitCost"].value_counts()
# Out:
# WarehouseId  ItemId           ItemUnitCost
# CA_1         FOODS_1_002      8.88            340
#                               9.48            190
#                               7.88            120
#              FOODS_1_005      3.28            448
#                               3.54            363
#                                              ...
# WI_3         HOUSEHOLD_2_488  5.14             11
#              HOUSEHOLD_2_498  2.98             97
#                               2.96             18
#              HOUSEHOLD_2_501  7.97            156
#                               8.47             96
# Name: ItemUnitCost, Length: 12901, dtype: int64

# %%
all(df_orderline.apply(lambda r: r["ConfirmedDeliveryDate"] == r["PlannedShipmentDate"] and r["ConfirmedDeliveryDate"] == r["RequestedDeliveryDate"], axis=1))
# Out:
# True

# %%
df_orderline.columns
# Out:
# Index(['ConfirmedDeliveryDate', 'ItemId', 'ItemUnitCost', 'OrderId',
#        'OrderLineId', 'OrderLineQuantity', 'OrderLineStatus',
#        'PlannedShipmentDate', 'PurchaseOrderLineNumber',
#        'RequestedDeliveryDate', 'WarehouseId'],
#       dtype='object')

# %%
# TODO: Confirm use which Date
df_orderline = df_orderline.drop(columns=[
    "OrderId", "OrderLineId", "PurchaseOrderLineNumber", "OrderLineStatus", "ConfirmedDeliveryDate", "PlannedShipmentDate"
])

# %%
df_orderline.head(5)
# Out:
#           ItemId  ItemUnitCost  OrderLineQuantity RequestedDeliveryDate  \
# 0  HOBBIES_1_003       3669.62                  3            2014-02-07
# 1  HOBBIES_1_003       3669.62                  2            2014-02-09
# 2  HOBBIES_1_003       3669.62                  1            2014-02-12
# 3  HOBBIES_1_003       3669.62                  1            2014-02-14
# 4  HOBBIES_1_003       3669.62                  1            2014-02-15
#
#   WarehouseId
# 0        CA_1
# 1        CA_1
# 2        CA_1
# 3        CA_1
# 4        CA_1

# %%
def check_price_same_in_one_day(group: pd.DataFrame):
    assert group["ItemUnitCost"].nunique() == 1

# %%
# Notes: Passed 04/20/2022, disabled to skip the long checking time. Seems only 1 record for 1 index
# df_orderline.groupby(["WarehouseId", "RequestedDeliveryDate", "ItemId"]).apply(check_price_same_in_one_day)

# %%
df_sales = df_orderline.groupby(["WarehouseId", "RequestedDeliveryDate", "ItemId"]).agg(
    {"OrderLineQuantity": np.sum, "ItemUnitCost": np.mean}
).reset_index()

# %%
df_sales = df_sales.rename(columns={
    "RequestedDeliveryDate": "Date",
    "OrderLineQuantity": "Sales",
    "ItemUnitCost": "Price",
})

# %%
df_sales
# Out:
#         WarehouseId        Date           ItemId  Sales  Price
# 0              CA_1  2011-01-29      FOODS_1_005      3   2.94
# 1              CA_1  2011-01-29      FOODS_1_011      2   2.28
# 2              CA_1  2011-01-29      FOODS_1_032     23   1.00
# 3              CA_1  2011-01-29      FOODS_1_035      3   2.28
# 4              CA_1  2011-01-29      FOODS_1_036      3   1.50
# ...             ...         ...              ...    ...    ...
# 3143781        WI_3  2016-05-22  HOUSEHOLD_2_417      2   3.97
# 3143782        WI_3  2016-05-22  HOUSEHOLD_2_449      2   5.64
# 3143783        WI_3  2016-05-22  HOUSEHOLD_2_486      1   5.97
# 3143784        WI_3  2016-05-22  HOUSEHOLD_2_488      1   4.97
# 3143785        WI_3  2016-05-22  HOUSEHOLD_2_501      1   7.97
#
# [3143786 rows x 5 columns]

# %%
df_sales["WarehouseId"].unique()
# Out:
# array(['CA_1', 'CA_2', 'CA_3', 'CA_4', 'TX_1', 'TX_2', 'TX_3', 'WI_1',
#        'WI_2', 'WI_3'], dtype=object)

# %%
df_sales["Date"].min(), df_sales["Date"].max()
# Out:
# ('2011-01-29', '2016-05-22')

# %% [markdown]
# ### Check the price in OrderLine v.s. in storage assignment

# %%
def compare_price(store_name, sku_name):
    in_storage_assignment = df_sku_info[
        df_sku_info["WarehouseId"] == store_name
    ][
        df_sku_info["ItemId"] == sku_name
    ]["UnitPrice"].unique()

    in_order_line = df_sales[
        df_sales["WarehouseId"] == store_name
    ][
        df_sales["ItemId"] == sku_name
    ]["Price"]

    print(in_storage_assignment, in_order_line.mean(), in_order_line.unique())

# %%
compare_price("CA_1", "HOUSEHOLD_2_417")
# Out:
# /home/Jinyu/anaconda3/envs/maro/lib/python3.7/site-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# [3.97] 3.9699999999999998 [3.97]
# /home/Jinyu/anaconda3/envs/maro/lib/python3.7/site-packages/ipykernel_launcher.py:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   # This is added back by InteractiveShellApp.init_path()

# %%
compare_price("CA_1", "FOODS_1_002")
# Out:
# /home/Jinyu/anaconda3/envs/maro/lib/python3.7/site-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# [8.87] 8.87076923076923 [7.88 8.88 9.48]
# /home/Jinyu/anaconda3/envs/maro/lib/python3.7/site-packages/ipykernel_launcher.py:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   # This is added back by InteractiveShellApp.init_path()

# %%
compare_price("CA_1", "FOODS_1_005")
# Out:
# /home/Jinyu/anaconda3/envs/maro/lib/python3.7/site-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# [3.35] 3.3507880133185353 [2.94 3.28 3.54]
# /home/Jinyu/anaconda3/envs/maro/lib/python3.7/site-packages/ipykernel_launcher.py:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   # This is added back by InteractiveShellApp.init_path()

# %%
compare_price("WI_3", "HOUSEHOLD_2_498")
# Out:
# /home/Jinyu/anaconda3/envs/maro/lib/python3.7/site-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# /home/Jinyu/anaconda3/envs/maro/lib/python3.7/site-packages/ipykernel_launcher.py:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   # This is added back by InteractiveShellApp.init_path()
# [2.98] 2.976869565217391 [2.98 2.96]

# %%
compare_price("WI_3", "HOUSEHOLD_2_501")
# Out:
# /home/Jinyu/anaconda3/envs/maro/lib/python3.7/site-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# /home/Jinyu/anaconda3/envs/maro/lib/python3.7/site-packages/ipykernel_launcher.py:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   # This is added back by InteractiveShellApp.init_path()
# [8.16] 8.16047619047619 [8.47 7.97]

# %% [markdown]
# ### Dump Sales data to csv and fill 0

# %%
# df_SCI = df_sales.rename(columns={
#     "WarehouseId": "StoreId",
# })
# df_SCI.head(5)
# Out:
#   StoreId        Date       ItemId  Sales  Price
# 0    CA_1  2011-01-29  FOODS_1_005      3   2.94
# 1    CA_1  2011-01-29  FOODS_1_011      2   2.28
# 2    CA_1  2011-01-29  FOODS_1_032     23   1.00
# 3    CA_1  2011-01-29  FOODS_1_035      3   2.28
# 4    CA_1  2011-01-29  FOODS_1_036      3   1.50

# %%
# len(df_SCI)
# Out:
# 3143786

# %%
# df_SCI["Date"] = pd.to_datetime(df_SCI["Date"])

# start_date, end_date = df_SCI["Date"].min(), df_SCI["Date"].max()
# total_num_days = (end_date - start_date).days + 1

# df_date = pd.DataFrame(data={
#     'Date': pd.date_range(start_date, end_date)
# })

# %%
# for (store_id, item_id), group in df_SCI.groupby(['StoreId', 'ItemId']):
#     print(len(group))
#     group = group.sort_values(by="Date")
#     group = pd.merge(df_date, group, on=['Date'], how='left')
#     group['StoreId'].fillna(store_id, inplace=True)
#     group['ItemId'].fillna(item_id, inplace=True)
#     group['Price'].fillna(group['Price'].mean(), inplace=True)
#     group['Sales'].fillna(0, inplace=True)
#     group['Sales'] = group['Sales'].astype(int)
#     break

# print(store_id, item_id)
# group
# Out:
# 650
# CA_1 FOODS_1_002
#            Date StoreId       ItemId  Sales     Price
# 0    2011-01-29    CA_1  FOODS_1_002      0  8.870769
# 1    2011-01-30    CA_1  FOODS_1_002      1  7.880000
# 2    2011-01-31    CA_1  FOODS_1_002      0  8.870769
# 3    2011-02-01    CA_1  FOODS_1_002      1  7.880000
# 4    2011-02-02    CA_1  FOODS_1_002      1  7.880000
# ...         ...     ...          ...    ...       ...
# 1936 2016-05-18    CA_1  FOODS_1_002      1  9.480000
# 1937 2016-05-19    CA_1  FOODS_1_002      0  8.870769
# 1938 2016-05-20    CA_1  FOODS_1_002      1  9.480000
# 1939 2016-05-21    CA_1  FOODS_1_002      1  9.480000
# 1940 2016-05-22    CA_1  FOODS_1_002      2  9.480000
#
# [1941 rows x 5 columns]

# %%
# def fill_with_0_sales(group):
#     info = f"Record Number: {len(group)} "
#     group = group.sort_values(by="Date").reset_index()
#     store_id, item_id, mean_price = group.iloc[0]['StoreId'], group.iloc[0]['ItemId'], group["Price"].mean()
    
#     group = pd.merge(df_date, group, on=['Date'], how='left')
#     group['StoreId'].fillna(store_id, inplace=True)
#     group['ItemId'].fillna(item_id, inplace=True)
#     group['Price'].fillna(mean_price, inplace=True)
#     group['Sales'].fillna(0, inplace=True)
#     group['Sales'] = group['Sales'].astype(int)
    
#     info += f"-> {len(group)}"
#     print(info)
#     return group

# df_SCI_all = df_SCI.groupby(['StoreId', 'ItemId']).apply(fill_with_0_sales).reset_index(drop=True)
# Out:
# Record Number: 650 -> 1941
# Record Number: 901 -> 1941
# Record Number: 578 -> 1941
# Record Number: 1295 -> 1941
# Record Number: 578 -> 1941
# Record Number: 110 -> 1941
# Record Number: 657 -> 1941
# Record Number: 1444 -> 1941
# Record Number: 645 -> 1941
# Record Number: 1221 -> 1941
# Record Number: 1376 -> 1941
# Record Number: 685 -> 1941
# Record Number: 486 -> 1941
# Record Number: 1278 -> 1941
# Record Number: 262 -> 1941
# Record Number: 1226 -> 1941
# Record Number: 1223 -> 1941
# Record Number: 821 -> 1941
# Record Number: 973 -> 1941
# Record Number: 1147 -> 1941
# Record Number: 244 -> 1941
# Record Number: 784 -> 1941
# Record Number: 1184 -> 1941
# Record Number: 652 -> 1941
# Record Number: 262 -> 1941
# Record Number: 176 -> 1941
# Record Number: 213 -> 1941
# Record Number: 240 -> 1941
# Record Number: 283 -> 1941
# Record Number: 406 -> 1941
# Record Number: 123 -> 1941
# Record Number: 28 -> 1941
# Record Number: 1063 -> 1941
# Record Number: 1091 -> 1941
# Record Number: 112 -> 1941
# Record Number: 405 -> 1941
# Record Number: 302 -> 1941
# Record Number: 105 -> 1941
# Record Number: 233 -> 1941
# Record Number: 362 -> 1941
# Record Number: 301 -> 1941
# Record Number: 285 -> 1941
# Record Number: 115 -> 1941
# Record Number: 252 -> 1941

# %%
# df_SCI_all = df_SCI_all.drop(columns=["index"])
# df_SCI_all
# Out:
#               Date StoreId           ItemId  Sales     Price
# 0       2011-01-29    CA_1      FOODS_1_002      0  8.870769
# 1       2011-01-30    CA_1      FOODS_1_002      1  7.880000
# 2       2011-01-31    CA_1      FOODS_1_002      0  8.870769
# 3       2011-02-01    CA_1      FOODS_1_002      1  7.880000
# 4       2011-02-02    CA_1      FOODS_1_002      1  7.880000
# ...            ...     ...              ...    ...       ...
# 9704995 2016-05-18    WI_3  HOUSEHOLD_2_501      0  8.160476
# 9704996 2016-05-19    WI_3  HOUSEHOLD_2_501      0  8.160476
# 9704997 2016-05-20    WI_3  HOUSEHOLD_2_501      0  8.160476
# 9704998 2016-05-21    WI_3  HOUSEHOLD_2_501      1  7.970000
# 9704999 2016-05-22    WI_3  HOUSEHOLD_2_501      1  7.970000
#
# [9705000 rows x 5 columns]

# %%
# df_SCI.to_csv(os.path.join(data_dir, "sales.csv"), index=False)
# df_SCI_all.to_csv(os.path.join(data_dir, "sales_0-filled.csv"), index=False)

# %% [markdown]
# ## Route

# %%
df_route = pd.read_parquet(os.path.join(src_dir, "routes.parquet"))
df_route.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 252 entries, 108 to 11
# Data columns (total 7 columns):
# StartingLocationId    252 non-null object
# EndingLocationId      252 non-null object
# Capacity              0 non-null float64
# UnitOfDuration        252 non-null object
# RouteId               252 non-null object
# TransportationCost    252 non-null float64
# Duration              252 non-null int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 15.8+ KB

# %%
df_route
# Out:
#     StartingLocationId EndingLocationId  Capacity UnitOfDuration    RouteId  \
# 108          STRG_CA_1             TX_1       NaN           days   ROUTE_10
# 109          STRG_CA_1             TX_1       NaN           days  ROUTE_136
# 132          STRG_CA_1             TX_2       NaN           days   ROUTE_11
# 133          STRG_CA_1             TX_2       NaN           days  ROUTE_137
# 156          STRG_CA_1             TX_3       NaN           days   ROUTE_12
# ..                 ...              ...       ...            ...        ...
# 7           PLANT_WH_1        STRG_TX_1       NaN           days  ROUTE_130
# 8           PLANT_WH_0        STRG_WI_1       NaN           days    ROUTE_2
# 9           PLANT_WH_0        STRG_WI_1       NaN           days  ROUTE_128
# 10          PLANT_WH_1        STRG_WI_1       NaN           days    ROUTE_5
# 11          PLANT_WH_1        STRG_WI_1       NaN           days  ROUTE_131
#
#      TransportationCost  Duration
# 108                0.96         2
# 109                0.76         3
# 132                0.97         2
# 133                0.75         3
# 156                0.84         3
# ..                  ...       ...
# 7                  0.77         3
# 8                  0.75         3
# 9                  1.01         2
# 10                 0.72         3
# 11                 0.98         2
#
# [252 rows x 7 columns]

# %%
df_route["RouteId"].nunique()
# Out:
# 252

# %%
df_route["StartingLocationId"].unique()
# Out:
# array(['STRG_CA_1', 'STRG_TX_1', 'STRG_WI_1', 'CA_1', 'CA_2', 'CA_3',
#        'CA_4', 'TX_1', 'TX_2', 'TX_3', 'WI_1', 'WI_2', 'WI_3',
#        'PLANT_WH_0', 'PLANT_WH_1'], dtype=object)

# %%
df_route["EndingLocationId"].unique()
# Out:
# array(['TX_1', 'TX_2', 'TX_3', 'WI_1', 'WI_2', 'WI_3', 'CA_1', 'CA_2',
#        'CA_3', 'CA_4', 'STRG_CA_1', 'STRG_TX_1', 'STRG_WI_1'],
#       dtype=object)

# %%
df_route[df_route["StartingLocationId"].isin(['PLANT_WH_0', 'PLANT_WH_1'])]
# Out:
#    StartingLocationId EndingLocationId  Capacity UnitOfDuration    RouteId  \
# 0          PLANT_WH_0        STRG_CA_1       NaN           days    ROUTE_0
# 1          PLANT_WH_0        STRG_CA_1       NaN           days  ROUTE_126
# 2          PLANT_WH_1        STRG_CA_1       NaN           days    ROUTE_3
# 3          PLANT_WH_1        STRG_CA_1       NaN           days  ROUTE_129
# 4          PLANT_WH_0        STRG_TX_1       NaN           days    ROUTE_1
# 5          PLANT_WH_0        STRG_TX_1       NaN           days  ROUTE_127
# 6          PLANT_WH_1        STRG_TX_1       NaN           days    ROUTE_4
# 7          PLANT_WH_1        STRG_TX_1       NaN           days  ROUTE_130
# 8          PLANT_WH_0        STRG_WI_1       NaN           days    ROUTE_2
# 9          PLANT_WH_0        STRG_WI_1       NaN           days  ROUTE_128
# 10         PLANT_WH_1        STRG_WI_1       NaN           days    ROUTE_5
# 11         PLANT_WH_1        STRG_WI_1       NaN           days  ROUTE_131
#
#     TransportationCost  Duration
# 0                 0.36         5
# 1                 0.66         4
# 2                 0.39         5
# 3                 0.49         5
# 4                 0.76         3
# 5                 0.40         5
# 6                 0.95         2
# 7                 0.77         3
# 8                 0.75         3
# 9                 1.01         2
# 10                0.72         3
# 11                0.98         2

# %%
df_route[df_route["EndingLocationId"].isin(['CA_2'])]
# Out:
#    StartingLocationId EndingLocationId  Capacity UnitOfDuration    RouteId  \
# 36          STRG_CA_1             CA_2       NaN           days    ROUTE_7
# 37          STRG_CA_1             CA_2       NaN           days  ROUTE_133
# 38          STRG_TX_1             CA_2       NaN           days   ROUTE_17
# 39          STRG_TX_1             CA_2       NaN           days  ROUTE_143
# 40          STRG_WI_1             CA_2       NaN           days   ROUTE_27
# 41          STRG_WI_1             CA_2       NaN           days  ROUTE_153
# 42               CA_1             CA_2       NaN           days   ROUTE_36
# 43               CA_1             CA_2       NaN           days  ROUTE_162
# 44               CA_3             CA_2       NaN           days   ROUTE_55
# 45               CA_3             CA_2       NaN           days  ROUTE_181
# 46               CA_4             CA_2       NaN           days   ROUTE_64
# 47               CA_4             CA_2       NaN           days  ROUTE_190
# 48               TX_1             CA_2       NaN           days   ROUTE_73
# 49               TX_1             CA_2       NaN           days  ROUTE_199
# 50               TX_2             CA_2       NaN           days   ROUTE_82
# 51               TX_2             CA_2       NaN           days  ROUTE_208
# 52               TX_3             CA_2       NaN           days   ROUTE_91
# 53               TX_3             CA_2       NaN           days  ROUTE_217
# 54               WI_1             CA_2       NaN           days  ROUTE_100
# 55               WI_1             CA_2       NaN           days  ROUTE_226
# 56               WI_2             CA_2       NaN           days  ROUTE_109
# 57               WI_2             CA_2       NaN           days  ROUTE_235
# 58               WI_3             CA_2       NaN           days  ROUTE_118
# 59               WI_3             CA_2       NaN           days  ROUTE_244
#
#     TransportationCost  Duration
# 36                0.33         5
# 37                0.65         4
# 38                0.87         2
# 39                0.98         2
# 40                0.82         3
# 41                1.10         1
# 42                0.43         5
# 43                0.64         4
# 44                0.61         4
# 45                0.29         6
# 46                0.57         4
# 47                0.50         5
# 48                0.71         3
# 49                0.92         2
# 50                1.20         1
# 51                0.87         2
# 52                0.91         2
# 53                0.89         2
# 54                0.82         3
# 55                1.01         2
# 56                0.86         2
# 57                1.12         1
# 58                0.97         2
# 59                0.75         3

# %%
df_route[df_route["Duration"] == 0]
# Out:
#     StartingLocationId EndingLocationId  Capacity UnitOfDuration    RouteId  \
# 210               CA_1             WI_2       NaN           days   ROUTE_43
# 168               CA_4             TX_3       NaN           days   ROUTE_68
# 98                TX_2             CA_4       NaN           days   ROUTE_84
# 247               TX_3             WI_3       NaN           days  ROUTE_224
# 152               WI_2             TX_2       NaN           days  ROUTE_113
#
#      TransportationCost  Duration
# 210                1.40         0
# 168                1.29         0
# 98                 1.25         0
# 247                1.24         0
# 152                1.26         0

# %%
df_route = df_route.drop(columns=["UnitOfDuration"])
df_route
# Out:
#     StartingLocationId EndingLocationId  Capacity    RouteId  \
# 108          STRG_CA_1             TX_1       NaN   ROUTE_10
# 109          STRG_CA_1             TX_1       NaN  ROUTE_136
# 132          STRG_CA_1             TX_2       NaN   ROUTE_11
# 133          STRG_CA_1             TX_2       NaN  ROUTE_137
# 156          STRG_CA_1             TX_3       NaN   ROUTE_12
# ..                 ...              ...       ...        ...
# 7           PLANT_WH_1        STRG_TX_1       NaN  ROUTE_130
# 8           PLANT_WH_0        STRG_WI_1       NaN    ROUTE_2
# 9           PLANT_WH_0        STRG_WI_1       NaN  ROUTE_128
# 10          PLANT_WH_1        STRG_WI_1       NaN    ROUTE_5
# 11          PLANT_WH_1        STRG_WI_1       NaN  ROUTE_131
#
#      TransportationCost  Duration
# 108                0.96         2
# 109                0.76         3
# 132                0.97         2
# 133                0.75         3
# 156                0.84         3
# ..                  ...       ...
# 7                  0.77         3
# 8                  0.75         3
# 9                  1.01         2
# 10                 0.72         3
# 11                 0.98         2
#
# [252 rows x 6 columns]

# %%
# TODO: Confirm the meaning of TransportationCost.
# Due to <<SCI_MARO_Mapping.xlsx>>: per unit. Danny: for whole duration

# TODO: No connection between Plant/Warehouse and Vendors
# no vlt infos
# no price differences among different vendors -> no need to have several vendors for 1 same product/component

# %% [markdown]
# # Build up config.yml from raw data

# %%
from typing import Dict

from maro.simulator.scenarios.supply_chain.objects import SkuMeta
# Out:
# /home/Jinyu/anaconda3/envs/maro/lib/python3.7/site-packages/scipy/__init__.py:149: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.16.1
#   UserWarning)

# %% [markdown]
# ## Sample a sub-dataset

# %% [markdown]
# ## Info for SKU Meta

# %%
df_item.head(5)
# Out:
#             ItemId  IsItemTypeFinishedGood VendorId
# 0      FOODS_3_535                    True  VNDR_28
# 1      FOODS_2_307                    True   VNDR_6
# 2      FOODS_2_307                    True  VNDR_24
# 3    HOBBIES_1_317                    True     None
# 4  HOUSEHOLD_1_467                    True   VNDR_5

# %%
df_bom.head(5)
# Out:
#           ItemId ComponentItemId  ComponentQuantity
# 0  HOBBIES_1_317        COMP_758                  7
# 1  HOBBIES_1_317       COMP_1112                  5
# 2  HOBBIES_1_317       COMP_1965                  9
# 3  HOBBIES_1_317       COMP_1202                  6
# 4  HOBBIES_1_317         COMP_99                  3

# %%
sku_name2id: Dict[str, int] = {}
sku_id2meta: Dict[int, SkuMeta] = {}

# %%
sku_id = 10

for sku_name in df_item["ItemId"].unique():
    sku_name2id[sku_name] = sku_id
    sku_id2meta[sku_id] = SkuMeta(id=sku_id, name=sku_name)
    sku_id += 1

# %%
len(sku_name2id), len(sku_id2meta)
# Out:
# (2322, 2322)

# %%
sku_id2meta[10]
# Out:
# SkuMeta(id=10, name='FOODS_3_535', output_units_per_lot=1, bom={})

# %%
for product_name, comp_name, quantity in zip(
    df_bom["ItemId"].to_numpy(),
    df_bom["ComponentItemId"].to_numpy(),
    df_bom["ComponentQuantity"].to_numpy(),
):
    assert product_name in sku_name2id
    assert sku_name2id[product_name] in sku_id2meta
    sku_id2meta[sku_name2id[product_name]].bom[sku_name2id[comp_name]] = quantity

# %%
for meta in sku_id2meta.values():
    if len(meta.bom) > 0:
        break
print(meta.name, len(meta.bom), "components in total:")
for comp_id, quantity in meta.bom.items():
    print(sku_id2meta[comp_id].name, "\t", quantity)
# Out:
# HOBBIES_1_317 29 components in total:
# COMP_758 	 7
# COMP_1112 	 5
# COMP_1965 	 9
# COMP_1202 	 6
# COMP_99 	 3
# COMP_490 	 4
# COMP_1649 	 7
# COMP_1311 	 1
# COMP_32 	 13
# COMP_227 	 1
# COMP_236 	 6
# COMP_1011 	 8
# COMP_1443 	 6
# COMP_348 	 4
# COMP_483 	 7
# COMP_1645 	 11
# COMP_2073 	 6
# COMP_1139 	 7
# COMP_1307 	 1
# COMP_1995 	 11
# COMP_1961 	 5
# COMP_1093 	 3
# COMP_216 	 6
# COMP_631 	 14
# COMP_934 	 6
# COMP_1910 	 12
# COMP_1694 	 2
# COMP_911 	 3
# COMP_1233 	 15

# %%
df_bom[df_bom["ItemId"] == "HOBBIES_1_317"]
# Out:
#            ItemId ComponentItemId  ComponentQuantity
# 0   HOBBIES_1_317        COMP_758                  7
# 1   HOBBIES_1_317       COMP_1112                  5
# 2   HOBBIES_1_317       COMP_1965                  9
# 3   HOBBIES_1_317       COMP_1202                  6
# 4   HOBBIES_1_317         COMP_99                  3
# 5   HOBBIES_1_317        COMP_490                  4
# 6   HOBBIES_1_317       COMP_1649                  7
# 7   HOBBIES_1_317       COMP_1311                  1
# 8   HOBBIES_1_317         COMP_32                 13
# 9   HOBBIES_1_317        COMP_227                  1
# 10  HOBBIES_1_317        COMP_236                  6
# 11  HOBBIES_1_317       COMP_1011                  8
# 12  HOBBIES_1_317       COMP_1443                  6
# 13  HOBBIES_1_317        COMP_348                  4
# 14  HOBBIES_1_317        COMP_483                  7
# 15  HOBBIES_1_317       COMP_1645                 11
# 16  HOBBIES_1_317       COMP_2073                  6
# 17  HOBBIES_1_317       COMP_1139                  7
# 18  HOBBIES_1_317       COMP_1307                  1
# 19  HOBBIES_1_317       COMP_1995                 11
# 20  HOBBIES_1_317       COMP_1961                  5
# 21  HOBBIES_1_317       COMP_1093                  3
# 22  HOBBIES_1_317        COMP_216                  6
# 23  HOBBIES_1_317        COMP_631                 14
# 24  HOBBIES_1_317        COMP_934                  6
# 25  HOBBIES_1_317       COMP_1910                 12
# 26  HOBBIES_1_317       COMP_1694                  2
# 27  HOBBIES_1_317        COMP_911                  3
# 28  HOBBIES_1_317       COMP_1233                 15

# %%
len(sku_name2id), len(sku_id2meta)
# Out:
# (2322, 2322)

# %%
config_sku_meta = ""

for meta in sku_id2meta.values():
    config_sku_meta += (
        f"    - id: {meta.id}\n"
        f"      name: {meta.name}\n"
    )
    
    if len(meta.bom) == 0:
        continue
        
    config_sku_meta += (
        "      output_units_per_lot: 1\n"
        "      bom:\n"
    )

    for comp_id, quantity in meta.bom.items():
        config_sku_meta += (
            f"        {sku_id2meta[comp_id].name}: {quantity}\n"
        )

# %%
print(config_sku_meta[:835])
# Out:
#     - id: 10
#       name: FOODS_3_535
#     - id: 11
#       name: FOODS_2_307
#     - id: 12
#       name: HOBBIES_1_317
#       output_units_per_lot: 1
#       bom:
#         COMP_758: 7
#         COMP_1112: 5
#         COMP_1965: 9
#         COMP_1202: 6
#         COMP_99: 3
#         COMP_490: 4
#         COMP_1649: 7
#         COMP_1311: 1
#         COMP_32: 13
#         COMP_227: 1
#         COMP_236: 6
#         COMP_1011: 8
#         COMP_1443: 6
#         COMP_348: 4
#         COMP_483: 7
#         COMP_1645: 11
#         COMP_2073: 6
#         COMP_1139: 7
#         COMP_1307: 1
#         COMP_1995: 11
#         COMP_1961: 5
#         COMP_1093: 3
#         COMP_216: 6
#         COMP_631: 14
#         COMP_934: 6
#         COMP_1910: 12
#         COMP_1694: 2
#         COMP_911: 3
#         COMP_1233: 15
#     - id: 13
#       name: HOUSEHOLD_1_467
#     - id: 14
#       name: FOODS_2_135

# %% [markdown]
# ## Facility info: name, storage capacity

# %%
df_facility
# Out:
#    WarehouseId  StorageCapacity
# 0         CA_1         13288.32
# 1         CA_2         12235.17
# 2         CA_3         17099.18
# 3         CA_4          9417.19
# 4         TX_1         11358.55
# 5         TX_2         12820.32
# 6         TX_3         11917.58
# 7         WI_1         11052.82
# 8         WI_2         13520.24
# 9         WI_3         12506.00
# 10  PLANT_WH_0      14522885.36
# 11  PLANT_WH_1      14522885.36
# 12   STRG_CA_1         52039.86
# 13   STRG_TX_1         36096.45
# 14   STRG_WI_1         37079.06

# %%
def facility_name2ref(name: str):
    if name.startswith("STRG"):
        return "WarehouseFacility"
    elif name.startswith("PLANT"):
        return "PlantFacility"
    else:
        return "StoreFacility"

# %%
# Key: facility name
facility_info: Dict[str, dict] = {}

# %%
for facility_name, capacity in zip(
    df_facility["WarehouseId"].to_numpy(),
    df_facility["StorageCapacity"].to_numpy(),
):
    ref = facility_name2ref(facility_name)
    facility_info[facility_name] = {
        "ref": ref,
        "storage_capacity": int(capacity),
        "skus": {},
    }

# %%
facility_info
# Out:
# {'CA_1': {'ref': 'StoreFacility', 'storage_capacity': 13288, 'skus': {}},
#  'CA_2': {'ref': 'StoreFacility', 'storage_capacity': 12235, 'skus': {}},
#  'CA_3': {'ref': 'StoreFacility', 'storage_capacity': 17099, 'skus': {}},
#  'CA_4': {'ref': 'StoreFacility', 'storage_capacity': 9417, 'skus': {}},
#  'TX_1': {'ref': 'StoreFacility', 'storage_capacity': 11358, 'skus': {}},
#  'TX_2': {'ref': 'StoreFacility', 'storage_capacity': 12820, 'skus': {}},
#  'TX_3': {'ref': 'StoreFacility', 'storage_capacity': 11917, 'skus': {}},
#  'WI_1': {'ref': 'StoreFacility', 'storage_capacity': 11052, 'skus': {}},
#  'WI_2': {'ref': 'StoreFacility', 'storage_capacity': 13520, 'skus': {}},
#  'WI_3': {'ref': 'StoreFacility', 'storage_capacity': 12506, 'skus': {}},
#  'PLANT_WH_0': {'ref': 'PlantFacility',
#   'storage_capacity': 14522885,
#   'skus': {}},
#  'PLANT_WH_1': {'ref': 'PlantFacility',
#   'storage_capacity': 14522885,
#   'skus': {}},
#  'STRG_CA_1': {'ref': 'WarehouseFacility',
#   'storage_capacity': 52039,
#   'skus': {}},
#  'STRG_TX_1': {'ref': 'WarehouseFacility',
#   'storage_capacity': 36096,
#   'skus': {}},
#  'STRG_WI_1': {'ref': 'WarehouseFacility',
#   'storage_capacity': 37079,
#   'skus': {}}}

# %% [markdown]
# ## Facility info: distribution related

# %%
df_route
# Out:
#     StartingLocationId EndingLocationId  Capacity    RouteId  \
# 108          STRG_CA_1             TX_1       NaN   ROUTE_10
# 109          STRG_CA_1             TX_1       NaN  ROUTE_136
# 132          STRG_CA_1             TX_2       NaN   ROUTE_11
# 133          STRG_CA_1             TX_2       NaN  ROUTE_137
# 156          STRG_CA_1             TX_3       NaN   ROUTE_12
# ..                 ...              ...       ...        ...
# 7           PLANT_WH_1        STRG_TX_1       NaN  ROUTE_130
# 8           PLANT_WH_0        STRG_WI_1       NaN    ROUTE_2
# 9           PLANT_WH_0        STRG_WI_1       NaN  ROUTE_128
# 10          PLANT_WH_1        STRG_WI_1       NaN    ROUTE_5
# 11          PLANT_WH_1        STRG_WI_1       NaN  ROUTE_131
#
#      TransportationCost  Duration
# 108                0.96         2
# 109                0.76         3
# 132                0.97         2
# 133                0.75         3
# 156                0.84         3
# ..                  ...       ...
# 7                  0.77         3
# 8                  0.75         3
# 9                  1.01         2
# 10                 0.72         3
# 11                 0.98         2
#
# [252 rows x 6 columns]

# %%
for facility_name, vehicle_type, number in zip(
    df_route["StartingLocationId"].to_numpy(),
    df_route["RouteId"].to_numpy(),
    df_route["Capacity"].to_numpy(),
):
    assert facility_name in facility_info
    if "distribution" not in facility_info[facility_name]:
        facility_info[facility_name]["distribution"] = []
    facility_info[facility_name]["distribution"].append((vehicle_type, number))

# %%
np.isnan(facility_info["STRG_CA_1"]["distribution"][0][1])
# Out:
# True

# %% [markdown]
# ## Facility info (genral SKU info): unit order cost

# %%
df_distribution
# Out:
#     FacilityId  DistributionCapacity  OrderCost
# 0         CA_1                   inf       1.07
# 1         CA_2                   inf       1.02
# 2         CA_3                   inf       0.84
# 3         CA_4                   inf       0.95
# 4         TX_1                   inf       0.85
# 5         TX_2                   inf       1.46
# 6         TX_3                   inf       0.81
# 7         WI_1                   inf       1.07
# 8         WI_2                   inf       0.77
# 9         WI_3                   inf       1.13
# 10  PLANT_WH_0                   inf       0.06
# 11  PLANT_WH_1                   inf       0.10
# 12   STRG_CA_1                   inf       0.09
# 13   STRG_TX_1                   inf       0.07
# 14   STRG_WI_1                   inf       0.07

# %%
for facility_name, cost in zip(
    df_distribution["FacilityId"].to_numpy(),
    df_distribution["OrderCost"].to_numpy()
):
    assert facility_name in facility_info
    facility_info[facility_name]["unit_order_cost"] = cost

# %%
facility_info
# Out:
# {'CA_1': {'ref': 'StoreFacility',
#   'storage_capacity': 13288,
#   'skus': {},
#   'distribution': [('ROUTE_39', nan),
#    ('ROUTE_165', nan),
#    ('ROUTE_40', nan),
#    ('ROUTE_166', nan),
#    ('ROUTE_41', nan),
#    ('ROUTE_167', nan),
#    ('ROUTE_42', nan),
#    ('ROUTE_168', nan),
#    ('ROUTE_43', nan),
#    ('ROUTE_169', nan),
#    ('ROUTE_44', nan),
#    ('ROUTE_170', nan),
#    ('ROUTE_36', nan),
#    ('ROUTE_162', nan),
#    ('ROUTE_37', nan),
#    ('ROUTE_163', nan),
#    ('ROUTE_38', nan),
#    ('ROUTE_164', nan)],
#   'unit_order_cost': 1.07},
#  'CA_2': {'ref': 'StoreFacility',
#   'storage_capacity': 12235,
#   'skus': {},
#   'distribution': [('ROUTE_48', nan),
#    ('ROUTE_174', nan),
#    ('ROUTE_49', nan),
#    ('ROUTE_175', nan),
#    ('ROUTE_50', nan),
#    ('ROUTE_176', nan),
#    ('ROUTE_51', nan),
#    ('ROUTE_177', nan),
#    ('ROUTE_52', nan),
#    ('ROUTE_178', nan),
#    ('ROUTE_53', nan),
#    ('ROUTE_179', nan),
#    ('ROUTE_45', nan),
#    ('ROUTE_171', nan),
#    ('ROUTE_46', nan),
#    ('ROUTE_172', nan),
#    ('ROUTE_47', nan),
#    ('ROUTE_173', nan)],
#   'unit_order_cost': 1.02},
#  'CA_3': {'ref': 'StoreFacility',
#   'storage_capacity': 17099,
#   'skus': {},
#   'distribution': [('ROUTE_57', nan),
#    ('ROUTE_183', nan),
#    ('ROUTE_58', nan),
#    ('ROUTE_184', nan),
#    ('ROUTE_59', nan),
#    ('ROUTE_185', nan),
#    ('ROUTE_60', nan),
#    ('ROUTE_186', nan),
#    ('ROUTE_61', nan),
#    ('ROUTE_187', nan),
#    ('ROUTE_62', nan),
#    ('ROUTE_188', nan),
#    ('ROUTE_54', nan),
#    ('ROUTE_180', nan),
#    ('ROUTE_55', nan),
#    ('ROUTE_181', nan),
#    ('ROUTE_56', nan),
#    ('ROUTE_182', nan)],
#   'unit_order_cost': 0.84},
#  'CA_4': {'ref': 'StoreFacility',
#   'storage_capacity': 9417,
#   'skus': {},
#   'distribution': [('ROUTE_66', nan),
#    ('ROUTE_192', nan),
#    ('ROUTE_67', nan),
#    ('ROUTE_193', nan),
#    ('ROUTE_68', nan),
#    ('ROUTE_194', nan),
#    ('ROUTE_69', nan),
#    ('ROUTE_195', nan),
#    ('ROUTE_70', nan),
#    ('ROUTE_196', nan),
#    ('ROUTE_71', nan),
#    ('ROUTE_197', nan),
#    ('ROUTE_63', nan),
#    ('ROUTE_189', nan),
#    ('ROUTE_64', nan),
#    ('ROUTE_190', nan),
#    ('ROUTE_65', nan),
#    ('ROUTE_191', nan)],
#   'unit_order_cost': 0.95},
#  'TX_1': {'ref': 'StoreFacility',
#   'storage_capacity': 11358,
#   'skus': {},
#   'distribution': [('ROUTE_72', nan),
#    ('ROUTE_198', nan),
#    ('ROUTE_73', nan),
#    ('ROUTE_199', nan),
#    ('ROUTE_74', nan),
#    ('ROUTE_200', nan),
#    ('ROUTE_75', nan),
#    ('ROUTE_201', nan),
#    ('ROUTE_78', nan),
#    ('ROUTE_204', nan),
#    ('ROUTE_79', nan),
#    ('ROUTE_205', nan),
#    ('ROUTE_80', nan),
#    ('ROUTE_206', nan),
#    ('ROUTE_76', nan),
#    ('ROUTE_202', nan),
#    ('ROUTE_77', nan),
#    ('ROUTE_203', nan)],
#   'unit_order_cost': 0.85},
#  'TX_2': {'ref': 'StoreFacility',
#   'storage_capacity': 12820,
#   'skus': {},
#   'distribution': [('ROUTE_81', nan),
#    ('ROUTE_207', nan),
#    ('ROUTE_82', nan),
#    ('ROUTE_208', nan),
#    ('ROUTE_83', nan),
#    ('ROUTE_209', nan),
#    ('ROUTE_84', nan),
#    ('ROUTE_210', nan),
#    ('ROUTE_87', nan),
#    ('ROUTE_213', nan),
#    ('ROUTE_88', nan),
#    ('ROUTE_214', nan),
#    ('ROUTE_89', nan),
#    ('ROUTE_215', nan),
#    ('ROUTE_85', nan),
#    ('ROUTE_211', nan),
#    ('ROUTE_86', nan),
#    ('ROUTE_212', nan)],
#   'unit_order_cost': 1.46},
#  'TX_3': {'ref': 'StoreFacility',
#   'storage_capacity': 11917,
#   'skus': {},
#   'distribution': [('ROUTE_90', nan),
#    ('ROUTE_216', nan),
#    ('ROUTE_91', nan),
#    ('ROUTE_217', nan),
#    ('ROUTE_92', nan),
#    ('ROUTE_218', nan),
#    ('ROUTE_93', nan),
#    ('ROUTE_219', nan),
#    ('ROUTE_96', nan),
#    ('ROUTE_222', nan),
#    ('ROUTE_97', nan),
#    ('ROUTE_223', nan),
#    ('ROUTE_98', nan),
#    ('ROUTE_224', nan),
#    ('ROUTE_94', nan),
#    ('ROUTE_220', nan),
#    ('ROUTE_95', nan),
#    ('ROUTE_221', nan)],
#   'unit_order_cost': 0.81},
#  'WI_1': {'ref': 'StoreFacility',
#   'storage_capacity': 11052,
#   'skus': {},
#   'distribution': [('ROUTE_99', nan),
#    ('ROUTE_225', nan),
#    ('ROUTE_100', nan),
#    ('ROUTE_226', nan),
#    ('ROUTE_101', nan),
#    ('ROUTE_227', nan),
#    ('ROUTE_102', nan),
#    ('ROUTE_228', nan),
#    ('ROUTE_103', nan),
#    ('ROUTE_229', nan),
#    ('ROUTE_104', nan),
#    ('ROUTE_230', nan),
#    ('ROUTE_105', nan),
#    ('ROUTE_231', nan),
#    ('ROUTE_106', nan),
#    ('ROUTE_232', nan),
#    ('ROUTE_107', nan),
#    ('ROUTE_233', nan)],
#   'unit_order_cost': 1.07},
#  'WI_2': {'ref': 'StoreFacility',
#   'storage_capacity': 13520,
#   'skus': {},
#   'distribution': [('ROUTE_108', nan),
#    ('ROUTE_234', nan),
#    ('ROUTE_109', nan),
#    ('ROUTE_235', nan),
#    ('ROUTE_110', nan),
#    ('ROUTE_236', nan),
#    ('ROUTE_111', nan),
#    ('ROUTE_237', nan),
#    ('ROUTE_112', nan),
#    ('ROUTE_238', nan),
#    ('ROUTE_113', nan),
#    ('ROUTE_239', nan),
#    ('ROUTE_114', nan),
#    ('ROUTE_240', nan),
#    ('ROUTE_115', nan),
#    ('ROUTE_241', nan),
#    ('ROUTE_116', nan),
#    ('ROUTE_242', nan)],
#   'unit_order_cost': 0.77},
#  'WI_3': {'ref': 'StoreFacility',
#   'storage_capacity': 12506,
#   'skus': {},
#   'distribution': [('ROUTE_117', nan),
#    ('ROUTE_243', nan),
#    ('ROUTE_118', nan),
#    ('ROUTE_244', nan),
#    ('ROUTE_119', nan),
#    ('ROUTE_245', nan),
#    ('ROUTE_120', nan),
#    ('ROUTE_246', nan),
#    ('ROUTE_121', nan),
#    ('ROUTE_247', nan),
#    ('ROUTE_122', nan),
#    ('ROUTE_248', nan),
#    ('ROUTE_123', nan),
#    ('ROUTE_249', nan),
#    ('ROUTE_124', nan),
#    ('ROUTE_250', nan),
#    ('ROUTE_125', nan),
#    ('ROUTE_251', nan)],
#   'unit_order_cost': 1.13},
#  'PLANT_WH_0': {'ref': 'PlantFacility',
#   'storage_capacity': 14522885,
#   'skus': {},
#   'distribution': [('ROUTE_0', nan),
#    ('ROUTE_126', nan),
#    ('ROUTE_1', nan),
#    ('ROUTE_127', nan),
#    ('ROUTE_2', nan),
#    ('ROUTE_128', nan)],
#   'unit_order_cost': 0.06},
#  'PLANT_WH_1': {'ref': 'PlantFacility',
#   'storage_capacity': 14522885,
#   'skus': {},
#   'distribution': [('ROUTE_3', nan),
#    ('ROUTE_129', nan),
#    ('ROUTE_4', nan),
#    ('ROUTE_130', nan),
#    ('ROUTE_5', nan),
#    ('ROUTE_131', nan)],
#   'unit_order_cost': 0.1},
#  'STRG_CA_1': {'ref': 'WarehouseFacility',
#   'storage_capacity': 52039,
#   'skus': {},
#   'distribution': [('ROUTE_10', nan),
#    ('ROUTE_136', nan),
#    ('ROUTE_11', nan),
#    ('ROUTE_137', nan),
#    ('ROUTE_12', nan),
#    ('ROUTE_138', nan),
#    ('ROUTE_13', nan),
#    ('ROUTE_139', nan),
#    ('ROUTE_14', nan),
#    ('ROUTE_140', nan),
#    ('ROUTE_15', nan),
#    ('ROUTE_141', nan),
#    ('ROUTE_6', nan),
#    ('ROUTE_132', nan),
#    ('ROUTE_7', nan),
#    ('ROUTE_133', nan),
#    ('ROUTE_8', nan),
#    ('ROUTE_134', nan),
#    ('ROUTE_9', nan),
#    ('ROUTE_135', nan)],
#   'unit_order_cost': 0.09},
#  'STRG_TX_1': {'ref': 'WarehouseFacility',
#   'storage_capacity': 36096,
#   'skus': {},
#   'distribution': [('ROUTE_16', nan),
#    ('ROUTE_142', nan),
#    ('ROUTE_17', nan),
#    ('ROUTE_143', nan),
#    ('ROUTE_18', nan),
#    ('ROUTE_144', nan),
#    ('ROUTE_19', nan),
#    ('ROUTE_145', nan),
#    ('ROUTE_23', nan),
#    ('ROUTE_149', nan),
#    ('ROUTE_24', nan),
#    ('ROUTE_150', nan),
#    ('ROUTE_25', nan),
#    ('ROUTE_151', nan),
#    ('ROUTE_20', nan),
#    ('ROUTE_146', nan),
#    ('ROUTE_21', nan),
#    ('ROUTE_147', nan),
#    ('ROUTE_22', nan),
#    ('ROUTE_148', nan)],
#   'unit_order_cost': 0.07},
#  'STRG_WI_1': {'ref': 'WarehouseFacility',
#   'storage_capacity': 37079,
#   'skus': {},
#   'distribution': [('ROUTE_26', nan),
#    ('ROUTE_152', nan),
#    ('ROUTE_27', nan),
#    ('ROUTE_153', nan),
#    ('ROUTE_28', nan),
#    ('ROUTE_154', nan),
#    ('ROUTE_29', nan),
#    ('ROUTE_155', nan),
#    ('ROUTE_30', nan),
#    ('ROUTE_156', nan),
#    ('ROUTE_31', nan),
#    ('ROUTE_157', nan),
#    ('ROUTE_32', nan),
#    ('ROUTE_158', nan),
#    ('ROUTE_33', nan),
#    ('ROUTE_159', nan),
#    ('ROUTE_34', nan),
#    ('ROUTE_160', nan),
#    ('ROUTE_35', nan),
#    ('ROUTE_161', nan)],
#   'unit_order_cost': 0.07}}

# %% [markdown]
# ## Facility SKU info: price, init stock, unit storage cost

# %%
df_sku_info
# Out:
#            ItemId WarehouseId  UnitPrice  StorageCost  InventoryOnHand
# 0        COMP_758  PLANT_WH_0       1.18      0.00064           540.22
# 1       COMP_1112  PLANT_WH_0       0.94      0.00046          6388.35
# 2       COMP_1965  PLANT_WH_0       0.65      0.00022          1581.49
# 3       COMP_1202  PLANT_WH_0       0.40      0.00022          3972.47
# 4         COMP_99  PLANT_WH_0       2.14      0.00068          4068.85
# ...           ...         ...        ...          ...              ...
# 9718  FOODS_3_822        TX_2       3.81      0.00248            17.64
# 9719  FOODS_3_822        TX_3       3.80      0.00131            19.05
# 9720  FOODS_3_822        WI_1       3.94      0.00172            14.60
# 9721  FOODS_3_822        WI_2       3.95      0.00238            27.89
# 9722  FOODS_3_822        WI_3       3.91      0.00207            21.10
#
# [9723 rows x 5 columns]

# %%
for sku_name, facility_name, price, unit_storage_cost, init_stock in zip(
    df_sku_info["ItemId"].to_numpy(),
    df_sku_info["WarehouseId"].to_numpy(),
    df_sku_info["UnitPrice"].to_numpy(),
    df_sku_info["StorageCost"].to_numpy(),
    df_sku_info["InventoryOnHand"].to_numpy(),
):
    assert facility_name in facility_info  
    assert sku_name in sku_name2id
    assert sku_name not in facility_info[facility_name]["skus"]
    facility_info[facility_name]["skus"][sku_name] = {
        "price": price,
        "unit_storage_cost": unit_storage_cost,
        "init_stock": int(init_stock),
    }

# %%
for facility_name in facility_info.keys():
    print(f"Facility {facility_name} has {len(facility_info[facility_name]['skus'])} SKU in total")
# Out:
# Facility CA_1 has 500 SKU in total
# Facility CA_2 has 500 SKU in total
# Facility CA_3 has 500 SKU in total
# Facility CA_4 has 500 SKU in total
# Facility TX_1 has 500 SKU in total
# Facility TX_2 has 500 SKU in total
# Facility TX_3 has 500 SKU in total
# Facility WI_1 has 500 SKU in total
# Facility WI_2 has 500 SKU in total
# Facility WI_3 has 500 SKU in total
# Facility PLANT_WH_0 has 1538 SKU in total
# Facility PLANT_WH_1 has 1685 SKU in total
# Facility STRG_CA_1 has 500 SKU in total
# Facility STRG_TX_1 has 500 SKU in total
# Facility STRG_WI_1 has 500 SKU in total

# %%
# Conclusion: Only Plant has Comps

for facility_name in facility_info.keys():
    for sku_name in facility_info[facility_name]["skus"].keys():
        if "COMP" in sku_name and "PLANT" not in facility_name:
            print(facility_name, sku_name)

# %%
# Conclusion: Every facility has valid price & unit storage cost for every item

for sku_name, facility_name, price, unit_storage_cost in zip(
    df_sku_info["ItemId"].to_numpy(),
    df_sku_info["WarehouseId"].to_numpy(),
    df_sku_info["UnitPrice"].to_numpy(),
    df_sku_info["StorageCost"].to_numpy()
):
    if np.isnan(price) or np.isnan(unit_storage_cost):
        print(facility_name, sku_name)

# %% [markdown]
# ## Facility SKU info: manufacture related

# %%
df_manufacture_info
# Out:
#            ItemId  ManufactureLeadTime  ManufactureRate  UnitMaterialCost  \
# 0   HOBBIES_1_317                    2            20.40            274.29
# 1   HOBBIES_2_143                    1            30.66             22.06
# 2   HOBBIES_1_069                    5            17.57            279.38
# 3   HOBBIES_1_366                    5            17.73            252.67
# 4   HOBBIES_1_017                    5            29.96           3427.17
# ..            ...                  ...              ...               ...
# 78  HOBBIES_1_405                    3            17.86            728.89
# 79  HOBBIES_1_044                    2            22.57            156.27
# 80  HOBBIES_1_357                    5            21.47            449.00
# 81  HOBBIES_1_045                    3            18.13           3403.99
# 82  HOBBIES_1_072                    3            22.39            825.20
#
#     UnitManufactureCost WarehouseId  output_lot_per_cycle
# 0                 40.13  PLANT_WH_0                 40.80
# 1                 14.70  PLANT_WH_0                 30.66
# 2                262.09  PLANT_WH_0                 87.85
# 3                354.83  PLANT_WH_0                 88.65
# 4               1018.65  PLANT_WH_0                149.80
# ..                  ...         ...                   ...
# 78               967.40  PLANT_WH_1                 53.58
# 79               231.64  PLANT_WH_1                 45.14
# 80               797.32  PLANT_WH_1                107.35
# 81              3213.75  PLANT_WH_1                 54.39
# 82               144.44  PLANT_WH_1                 67.17
#
# [83 rows x 7 columns]

# %%
for facility_name, sku_name, lt, rate, cost in zip(
    df_manufacture_info["WarehouseId"].to_numpy(),
    df_manufacture_info["ItemId"].to_numpy(),
    df_manufacture_info["ManufactureLeadTime"].to_numpy(),
    df_manufacture_info["ManufactureRate"].to_numpy(),
    df_manufacture_info["UnitManufactureCost"].to_numpy(),
):
    assert facility_name in facility_info
    assert sku_name in facility_info[facility_name]["skus"]
    
    facility_info[facility_name]["skus"][sku_name]["manufacture"] = {
        "leading_time": lt,
        "max_rate": int(rate * lt),  # the max_manufacture_rate in MARO means the pipeline throughput
        "unit_cost": cost / lt,  # the unit_manufacture_cost is per unit per tick in MARO
    }

# %% [markdown]
# ## Facility SKU info: seller related

# %%
df_sales.head(5)
# Out:
#   WarehouseId        Date       ItemId  Sales  Price
# 0        CA_1  2011-01-29  FOODS_1_005      3   2.94
# 1        CA_1  2011-01-29  FOODS_1_011      2   2.28
# 2        CA_1  2011-01-29  FOODS_1_032     23   1.00
# 3        CA_1  2011-01-29  FOODS_1_035      3   2.28
# 4        CA_1  2011-01-29  FOODS_1_036      3   1.50

# %%
start_date, end_date
# Out:
# ('2012-01-01', '2012-12-31')

# %%
df_sales["Date"].min(), df_sales["Date"].max()
# Out:
# ('2011-01-29', '2016-05-22')

# %%
df_sales.shape[0]
# Out:
# 3143786

# %%
df_demand = df_sales[df_sales["Date"] >= start_date][df_sales["Date"] <= end_date]
# Out:
# /home/Jinyu/anaconda3/envs/maro/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
df_demand.shape[0]
# Out:
# 488374

# %%
for store_name, group in df_demand.groupby("WarehouseId"):
    assert store_name in facility_info
    assert facility_name2ref(store_name) == "StoreFacility"
    
    for sku_name, per_sku in group.groupby("ItemId"):
        assert sku_name in facility_info[store_name]["skus"]
        facility_info[store_name]["skus"][sku_name]["seller"] = {
            "gamma": per_sku["Sales"].mean()  # TODO: update gamma strategy, convert to int or not?
        }
    
    group = group.sort_values(by="Date")
    group = group[["Date", "ItemId", "Sales", "Price"]]
    
    file_path = os.path.join(data_dir, f"{store_name}.csv")
    facility_info[store_name]["sales_path"] = file_path
    group.to_csv(file_path, index=False)

# %%
for store_name in facility_info.keys():
    if facility_name2ref(store_name) != "StoreFacility":
        continue
        
    for sku_name in facility_info[store_name]["skus"].keys():
        if "seller" not in facility_info[store_name]["skus"][sku_name]:
            facility_info[store_name]["skus"][sku_name]["seller"] = {"gamma": 0}

# %%
print(store_name)
group
# Out:
# STRG_WI_1
#                Date           ItemId  Sales     Price
# 2889025  2012-01-01      FOODS_1_005      1      3.28
# 2889099  2012-01-01    HOBBIES_1_408      4  11987.69
# 2889098  2012-01-01    HOBBIES_1_405      1   2481.07
# 2889097  2012-01-01    HOBBIES_1_388      3   1567.02
# 2889096  2012-01-01    HOBBIES_1_357      1   1888.95
# ...             ...              ...    ...       ...
# 2940521  2012-12-31      FOODS_3_131      4      1.00
# 2940522  2012-12-31      FOODS_3_149      1      2.50
# 2940523  2012-12-31      FOODS_3_174      3      5.98
# 2940506  2012-12-31      FOODS_2_307      4      2.50
# 2940617  2012-12-31  HOUSEHOLD_2_464      1      2.88
#
# [51593 rows x 4 columns]

# %% [markdown]
# ## Toplogy info

# %% [markdown]
# ### Route Info

# %%
df_route
# Out:
#     StartingLocationId EndingLocationId  Capacity    RouteId  \
# 108          STRG_CA_1             TX_1       NaN   ROUTE_10
# 109          STRG_CA_1             TX_1       NaN  ROUTE_136
# 132          STRG_CA_1             TX_2       NaN   ROUTE_11
# 133          STRG_CA_1             TX_2       NaN  ROUTE_137
# 156          STRG_CA_1             TX_3       NaN   ROUTE_12
# ..                 ...              ...       ...        ...
# 7           PLANT_WH_1        STRG_TX_1       NaN  ROUTE_130
# 8           PLANT_WH_0        STRG_WI_1       NaN    ROUTE_2
# 9           PLANT_WH_0        STRG_WI_1       NaN  ROUTE_128
# 10          PLANT_WH_1        STRG_WI_1       NaN    ROUTE_5
# 11          PLANT_WH_1        STRG_WI_1       NaN  ROUTE_131
#
#      TransportationCost  Duration
# 108                0.96         2
# 109                0.76         3
# 132                0.97         2
# 133                0.75         3
# 156                0.84         3
# ..                  ...       ...
# 7                  0.77         3
# 8                  0.75         3
# 9                  1.01         2
# 10                 0.72         3
# 11                 0.98         2
#
# [252 rows x 6 columns]

# %%
pairs = df_route[['StartingLocationId', 'EndingLocationId']].rename(columns={'StartingLocationId': 'Start', 'EndingLocationId': 'End'}).drop_duplicates()
pairs
# Out:
#           Start        End
# 108   STRG_CA_1       TX_1
# 132   STRG_CA_1       TX_2
# 156   STRG_CA_1       TX_3
# 180   STRG_CA_1       WI_1
# 204   STRG_CA_1       WI_2
# ..          ...        ...
# 2    PLANT_WH_1  STRG_CA_1
# 4    PLANT_WH_0  STRG_TX_1
# 6    PLANT_WH_1  STRG_TX_1
# 8    PLANT_WH_0  STRG_WI_1
# 10   PLANT_WH_1  STRG_WI_1
#
# [126 rows x 2 columns]

# %%
for end, group in pairs.groupby('End'):
    print(f"{end}: {group['Start'].unique()}")
# Out:
# CA_1: ['STRG_CA_1' 'STRG_TX_1' 'STRG_WI_1' 'CA_2' 'CA_3' 'CA_4' 'TX_1' 'TX_2'
#  'TX_3' 'WI_1' 'WI_2' 'WI_3']
# CA_2: ['STRG_CA_1' 'STRG_TX_1' 'STRG_WI_1' 'CA_1' 'CA_3' 'CA_4' 'TX_1' 'TX_2'
#  'TX_3' 'WI_1' 'WI_2' 'WI_3']
# CA_3: ['STRG_CA_1' 'STRG_TX_1' 'STRG_WI_1' 'CA_1' 'CA_2' 'CA_4' 'TX_1' 'TX_2'
#  'TX_3' 'WI_1' 'WI_2' 'WI_3']
# CA_4: ['STRG_CA_1' 'STRG_TX_1' 'STRG_WI_1' 'CA_1' 'CA_2' 'CA_3' 'TX_1' 'TX_2'
#  'TX_3' 'WI_1' 'WI_2' 'WI_3']
# STRG_CA_1: ['PLANT_WH_0' 'PLANT_WH_1']
# STRG_TX_1: ['PLANT_WH_0' 'PLANT_WH_1']
# STRG_WI_1: ['PLANT_WH_0' 'PLANT_WH_1']
# TX_1: ['STRG_CA_1' 'STRG_TX_1' 'STRG_WI_1' 'CA_1' 'CA_2' 'CA_3' 'CA_4' 'TX_2'
#  'TX_3' 'WI_1' 'WI_2' 'WI_3']
# TX_2: ['STRG_CA_1' 'STRG_TX_1' 'STRG_WI_1' 'CA_1' 'CA_2' 'CA_3' 'CA_4' 'TX_1'
#  'TX_3' 'WI_1' 'WI_2' 'WI_3']
# TX_3: ['STRG_CA_1' 'STRG_TX_1' 'STRG_WI_1' 'CA_1' 'CA_2' 'CA_3' 'CA_4' 'TX_1'
#  'TX_2' 'WI_1' 'WI_2' 'WI_3']
# WI_1: ['STRG_CA_1' 'STRG_TX_1' 'STRG_WI_1' 'CA_1' 'CA_2' 'CA_3' 'CA_4' 'TX_1'
#  'TX_2' 'TX_3' 'WI_2' 'WI_3']
# WI_2: ['STRG_CA_1' 'STRG_TX_1' 'STRG_WI_1' 'CA_1' 'CA_2' 'CA_3' 'CA_4' 'TX_1'
#  'TX_2' 'TX_3' 'WI_1' 'WI_3']
# WI_3: ['STRG_CA_1' 'STRG_TX_1' 'STRG_WI_1' 'CA_1' 'CA_2' 'CA_3' 'CA_4' 'TX_1'
#  'TX_2' 'TX_3' 'WI_1' 'WI_2']

# %% [markdown]
# ### Item Id List

# %%
df_item.head(5)
# Out:
#             ItemId  IsItemTypeFinishedGood VendorId
# 0      FOODS_3_535                    True  VNDR_28
# 1      FOODS_2_307                    True   VNDR_6
# 2      FOODS_2_307                    True  VNDR_24
# 3    HOBBIES_1_317                    True     None
# 4  HOUSEHOLD_1_467                    True   VNDR_5

# %%
COMPs = df_item[~df_item['IsItemTypeFinishedGood']]['ItemId'].unique()
COMPs
# Out:
# array(['COMP_758', 'COMP_1112', 'COMP_1965', ..., 'COMP_1661', 'COMP_537',
#        'COMP_1692'], dtype=object)

# %%
from_Plant = df_item[df_item['VendorId'].isnull()]['ItemId'].unique()
from_Plant
# Out:
# array(['HOBBIES_1_317', 'HOBBIES_1_003', 'HOBBIES_1_400', 'HOBBIES_2_143',
#        'HOBBIES_1_069', 'HOBBIES_1_366', 'HOBBIES_1_017', 'HOBBIES_1_239',
#        'HOBBIES_1_348', 'HOBBIES_1_319', 'HOBBIES_1_136', 'HOBBIES_1_331',
#        'HOBBIES_2_054', 'HOBBIES_1_303', 'HOBBIES_2_096', 'HOBBIES_1_371',
#        'HOBBIES_1_081', 'HOBBIES_1_247', 'HOBBIES_2_093', 'HOBBIES_1_173',
#        'HOBBIES_1_236', 'HOBBIES_1_230', 'HOBBIES_1_320', 'HOBBIES_1_305',
#        'HOBBIES_2_043', 'HOBBIES_2_004', 'HOBBIES_1_251', 'HOBBIES_1_283',
#        'HOBBIES_1_189', 'HOBBIES_1_403', 'HOBBIES_1_105', 'HOBBIES_1_098',
#        'HOBBIES_2_070', 'HOBBIES_1_150', 'HOBBIES_2_019', 'HOBBIES_2_064',
#        'HOBBIES_2_095', 'HOBBIES_1_372', 'HOBBIES_1_187', 'HOBBIES_1_351',
#        'HOBBIES_1_308', 'HOBBIES_1_408', 'HOBBIES_1_365', 'HOBBIES_1_122',
#        'HOBBIES_1_063', 'HOBBIES_1_394', 'HOBBIES_1_238', 'HOBBIES_1_235',
#        'HOBBIES_1_166', 'HOBBIES_1_181', 'HOBBIES_2_039', 'HOBBIES_1_167',
#        'HOBBIES_1_324', 'HOBBIES_1_347', 'HOBBIES_2_098', 'HOBBIES_1_121',
#        'HOBBIES_1_255', 'HOBBIES_1_227', 'HOBBIES_2_084', 'HOBBIES_1_388',
#        'HOBBIES_1_041', 'HOBBIES_1_328', 'HOBBIES_1_300', 'HOBBIES_1_361',
#        'HOBBIES_2_133', 'HOBBIES_1_407', 'HOBBIES_2_013', 'HOBBIES_2_012',
#        'HOBBIES_1_207', 'HOBBIES_1_090', 'HOBBIES_1_292', 'HOBBIES_1_242',
#        'HOBBIES_1_405', 'HOBBIES_1_206', 'HOBBIES_1_044', 'HOBBIES_1_414',
#        'HOBBIES_1_385', 'HOBBIES_1_299', 'HOBBIES_1_357', 'HOBBIES_2_103',
#        'HOBBIES_2_119', 'HOBBIES_1_045', 'HOBBIES_1_072'], dtype=object)

# %%
from_Vendor = df_item[~df_item['VendorId'].isnull()]['ItemId'].unique()
from_Vendor
# Out:
# array(['FOODS_3_535', 'FOODS_2_307', 'HOUSEHOLD_1_467', ..., 'COMP_1661',
#        'COMP_537', 'COMP_1692'], dtype=object)

# %%
products_from_vendor = [item for item in from_Vendor if item not in COMPs]
print(len(products_from_vendor))
products_from_vendor
# Out:
# 417
# ['FOODS_3_535',
#  'FOODS_2_307',
#  'HOUSEHOLD_1_467',
#  'FOODS_2_135',
#  'HOUSEHOLD_2_405',
#  'FOODS_2_180',
#  'FOODS_3_621',
#  'FOODS_2_149',
#  'FOODS_2_397',
#  'HOUSEHOLD_1_001',
#  'HOUSEHOLD_2_158',
#  'HOUSEHOLD_2_450',
#  'HOUSEHOLD_1_459',
#  'FOODS_3_686',
#  'FOODS_3_578',
#  'FOODS_3_210',
#  'FOODS_3_806',
#  'FOODS_3_063',
#  'HOUSEHOLD_2_120',
#  'HOUSEHOLD_2_219',
#  'FOODS_3_270',
#  'FOODS_3_761',
#  'FOODS_3_229',
#  'HOUSEHOLD_2_194',
#  'FOODS_3_025',
#  'HOUSEHOLD_1_188',
#  'FOODS_3_362',
#  'FOODS_2_143',
#  'HOUSEHOLD_2_063',
#  'HOUSEHOLD_2_113',
#  'FOODS_3_050',
#  'FOODS_2_129',
#  'FOODS_2_036',
#  'HOUSEHOLD_1_472',
#  'FOODS_1_036',
#  'HOUSEHOLD_1_154',
#  'FOODS_3_131',
#  'FOODS_3_799',
#  'FOODS_2_131',
#  'FOODS_3_197',
#  'HOUSEHOLD_1_400',
#  'HOUSEHOLD_1_135',
#  'FOODS_2_093',
#  'HOUSEHOLD_1_139',
#  'FOODS_3_421',
#  'FOODS_3_604',
#  'HOUSEHOLD_1_423',
#  'FOODS_1_076',
#  'HOUSEHOLD_2_467',
#  'HOUSEHOLD_2_366',
#  'FOODS_3_739',
#  'HOUSEHOLD_2_418',
#  'FOODS_3_182',
#  'HOUSEHOLD_1_446',
#  'FOODS_3_330',
#  'HOUSEHOLD_2_256',
#  'FOODS_2_099',
#  'HOUSEHOLD_2_124',
#  'FOODS_2_066',
#  'FOODS_3_316',
#  'FOODS_3_127',
#  'FOODS_3_218',
#  'HOUSEHOLD_1_339',
#  'FOODS_3_353',
#  'HOUSEHOLD_1_193',
#  'HOUSEHOLD_1_533',
#  'FOODS_3_494',
#  'FOODS_3_682',
#  'FOODS_2_259',
#  'HOUSEHOLD_1_300',
#  'FOODS_3_313',
#  'HOUSEHOLD_2_216',
#  'FOODS_3_132',
#  'FOODS_2_258',
#  'HOUSEHOLD_1_386',
#  'HOUSEHOLD_1_170',
#  'HOUSEHOLD_1_013',
#  'HOUSEHOLD_1_065',
#  'HOUSEHOLD_1_127',
#  'FOODS_2_257',
#  'FOODS_3_188',
#  'HOUSEHOLD_1_540',
#  'HOUSEHOLD_2_299',
#  'FOODS_2_154',
#  'FOODS_3_198',
#  'FOODS_3_801',
#  'FOODS_3_081',
#  'FOODS_3_176',
#  'HOUSEHOLD_1_047',
#  'FOODS_3_222',
#  'FOODS_3_048',
#  'HOUSEHOLD_2_316',
#  'FOODS_3_547',
#  'FOODS_1_011',
#  'HOUSEHOLD_1_230',
#  'HOUSEHOLD_2_300',
#  'FOODS_2_347',
#  'FOODS_2_058',
#  'HOUSEHOLD_2_220',
#  'HOUSEHOLD_1_350',
#  'FOODS_3_087',
#  'FOODS_1_152',
#  'FOODS_2_004',
#  'FOODS_3_588',
#  'HOUSEHOLD_2_237',
#  'FOODS_3_306',
#  'FOODS_3_243',
#  'FOODS_3_786',
#  'FOODS_3_049',
#  'FOODS_3_044',
#  'FOODS_3_574',
#  'HOUSEHOLD_2_383',
#  'HOUSEHOLD_1_525',
#  'FOODS_3_321',
#  'HOUSEHOLD_1_039',
#  'FOODS_1_067',
#  'FOODS_3_663',
#  'FOODS_2_040',
#  'HOUSEHOLD_2_189',
#  'HOUSEHOLD_2_062',
#  'FOODS_2_340',
#  'HOUSEHOLD_1_102',
#  'FOODS_2_275',
#  'FOODS_3_364',
#  'HOUSEHOLD_1_104',
#  'HOUSEHOLD_1_315',
#  'FOODS_3_746',
#  'HOUSEHOLD_2_014',
#  'FOODS_3_757',
#  'FOODS_1_106',
#  'FOODS_3_484',
#  'FOODS_3_754',
#  'HOUSEHOLD_2_417',
#  'FOODS_3_310',
#  'HOUSEHOLD_1_506',
#  'FOODS_3_548',
#  'HOUSEHOLD_1_077',
#  'HOUSEHOLD_2_208',
#  'HOUSEHOLD_1_106',
#  'HOUSEHOLD_2_064',
#  'FOODS_3_443',
#  'HOUSEHOLD_2_077',
#  'FOODS_1_115',
#  'FOODS_3_537',
#  'FOODS_1_156',
#  'FOODS_1_045',
#  'HOUSEHOLD_2_456',
#  'HOUSEHOLD_2_437',
#  'FOODS_3_174',
#  'FOODS_2_014',
#  'FOODS_3_490',
#  'HOUSEHOLD_1_258',
#  'FOODS_3_024',
#  'HOUSEHOLD_2_103',
#  'FOODS_2_080',
#  'HOUSEHOLD_2_031',
#  'FOODS_3_545',
#  'FOODS_3_557',
#  'FOODS_3_296',
#  'FOODS_2_388',
#  'FOODS_2_074',
#  'HOUSEHOLD_2_400',
#  'FOODS_3_202',
#  'FOODS_1_102',
#  'FOODS_3_219',
#  'FOODS_1_191',
#  'HOUSEHOLD_1_027',
#  'HOUSEHOLD_1_413',
#  'FOODS_3_493',
#  'FOODS_2_344',
#  'HOUSEHOLD_1_011',
#  'FOODS_1_089',
#  'FOODS_3_423',
#  'FOODS_3_636',
#  'HOUSEHOLD_1_068',
#  'FOODS_1_218',
#  'FOODS_3_405',
#  'FOODS_2_365',
#  'FOODS_3_326',
#  'FOODS_3_598',
#  'FOODS_3_710',
#  'FOODS_2_208',
#  'HOUSEHOLD_2_143',
#  'FOODS_3_412',
#  'HOUSEHOLD_1_049',
#  'FOODS_3_067',
#  'FOODS_2_181',
#  'FOODS_2_164',
#  'FOODS_3_274',
#  'FOODS_3_095',
#  'FOODS_1_005',
#  'FOODS_3_566',
#  'FOODS_3_787',
#  'FOODS_1_160',
#  'HOUSEHOLD_1_535',
#  'FOODS_3_013',
#  'HOUSEHOLD_2_015',
#  'HOUSEHOLD_1_299',
#  'FOODS_1_002',
#  'FOODS_2_202',
#  'HOUSEHOLD_2_288',
#  'FOODS_1_171',
#  'HOUSEHOLD_1_319',
#  'FOODS_3_010',
#  'HOUSEHOLD_2_419',
#  'HOUSEHOLD_2_110',
#  'HOUSEHOLD_2_222',
#  'FOODS_2_230',
#  'FOODS_3_731',
#  'HOUSEHOLD_1_245',
#  'FOODS_2_384',
#  'FOODS_3_272',
#  'FOODS_1_182',
#  'HOUSEHOLD_1_292',
#  'FOODS_3_073',
#  'FOODS_1_059',
#  'FOODS_3_165',
#  'HOUSEHOLD_2_320',
#  'HOUSEHOLD_1_374',
#  'HOUSEHOLD_2_008',
#  'FOODS_1_179',
#  'FOODS_3_723',
#  'HOUSEHOLD_1_360',
#  'FOODS_2_097',
#  'FOODS_3_617',
#  'HOUSEHOLD_2_051',
#  'FOODS_2_024',
#  'HOUSEHOLD_2_411',
#  'FOODS_2_079',
#  'HOUSEHOLD_1_119',
#  'FOODS_1_124',
#  'HOUSEHOLD_1_007',
#  'HOUSEHOLD_1_261',
#  'FOODS_3_250',
#  'FOODS_2_046',
#  'FOODS_3_625',
#  'FOODS_3_804',
#  'FOODS_3_610',
#  'FOODS_3_026',
#  'FOODS_3_736',
#  'FOODS_2_304',
#  'HOUSEHOLD_2_034',
#  'FOODS_3_788',
#  'FOODS_1_053',
#  'HOUSEHOLD_1_377',
#  'FOODS_3_065',
#  'FOODS_3_533',
#  'FOODS_2_072',
#  'FOODS_2_204',
#  'FOODS_3_594',
#  'FOODS_3_262',
#  'HOUSEHOLD_1_490',
#  'HOUSEHOLD_1_458',
#  'HOUSEHOLD_2_488',
#  'HOUSEHOLD_2_042',
#  'FOODS_3_345',
#  'HOUSEHOLD_2_227',
#  'FOODS_2_289',
#  'FOODS_1_172',
#  'HOUSEHOLD_1_125',
#  'FOODS_3_005',
#  'FOODS_3_559',
#  'FOODS_3_658',
#  'HOUSEHOLD_2_295',
#  'FOODS_1_213',
#  'FOODS_2_374',
#  'HOUSEHOLD_2_359',
#  'FOODS_3_583',
#  'HOUSEHOLD_2_386',
#  'HOUSEHOLD_2_289',
#  'FOODS_3_685',
#  'FOODS_3_169',
#  'HOUSEHOLD_2_252',
#  'FOODS_3_279',
#  'FOODS_2_206',
#  'FOODS_3_640',
#  'HOUSEHOLD_2_136',
#  'FOODS_2_229',
#  'FOODS_3_681',
#  'FOODS_1_180',
#  'FOODS_3_028',
#  'FOODS_3_447',
#  'FOODS_2_219',
#  'FOODS_3_159',
#  'HOUSEHOLD_2_267',
#  'FOODS_2_035',
#  'FOODS_2_001',
#  'HOUSEHOLD_2_203',
#  'HOUSEHOLD_2_178',
#  'FOODS_2_390',
#  'HOUSEHOLD_1_146',
#  'FOODS_3_576',
#  'HOUSEHOLD_2_101',
#  'HOUSEHOLD_1_475',
#  'FOODS_3_173',
#  'FOODS_3_149',
#  'FOODS_1_186',
#  'FOODS_1_075',
#  'FOODS_1_142',
#  'HOUSEHOLD_2_046',
#  'FOODS_3_509',
#  'HOUSEHOLD_1_191',
#  'HOUSEHOLD_2_050',
#  'HOUSEHOLD_1_534',
#  'HOUSEHOLD_1_149',
#  'HOUSEHOLD_1_307',
#  'HOUSEHOLD_2_223',
#  'FOODS_3_549',
#  'HOUSEHOLD_2_440',
#  'FOODS_2_332',
#  'HOUSEHOLD_1_401',
#  'FOODS_3_532',
#  'FOODS_2_291',
#  'HOUSEHOLD_2_065',
#  'HOUSEHOLD_1_113',
#  'FOODS_3_249',
#  'FOODS_3_459',
#  'HOUSEHOLD_2_058',
#  'FOODS_2_084',
#  'FOODS_1_022',
#  'HOUSEHOLD_1_536',
#  'HOUSEHOLD_2_118',
#  'HOUSEHOLD_1_018',
#  'FOODS_3_486',
#  'FOODS_2_333',
#  'FOODS_2_015',
#  'HOUSEHOLD_1_242',
#  'FOODS_3_284',
#  'FOODS_1_035',
#  'HOUSEHOLD_2_464',
#  'HOUSEHOLD_1_332',
#  'HOUSEHOLD_2_044',
#  'HOUSEHOLD_1_247',
#  'FOODS_3_361',
#  'FOODS_1_088',
#  'FOODS_3_774',
#  'FOODS_3_698',
#  'HOUSEHOLD_1_080',
#  'FOODS_1_187',
#  'HOUSEHOLD_2_501',
#  'FOODS_3_266',
#  'FOODS_3_231',
#  'HOUSEHOLD_1_144',
#  'FOODS_3_110',
#  'FOODS_3_323',
#  'FOODS_3_030',
#  'HOUSEHOLD_1_314',
#  'HOUSEHOLD_2_090',
#  'FOODS_2_369',
#  'HOUSEHOLD_2_498',
#  'FOODS_1_196',
#  'HOUSEHOLD_2_486',
#  'FOODS_3_394',
#  'FOODS_3_216',
#  'FOODS_3_642',
#  'HOUSEHOLD_2_052',
#  'FOODS_3_690',
#  'FOODS_3_760',
#  'FOODS_1_014',
#  'FOODS_1_061',
#  'FOODS_2_191',
#  'FOODS_2_314',
#  'FOODS_2_267',
#  'FOODS_1_026',
#  'HOUSEHOLD_1_117',
#  'FOODS_2_394',
#  'FOODS_3_387',
#  'FOODS_1_113',
#  'FOODS_3_061',
#  'HOUSEHOLD_1_277',
#  'HOUSEHOLD_2_209',
#  'FOODS_3_822',
#  'FOODS_2_251',
#  'FOODS_3_434',
#  'FOODS_3_253',
#  'HOUSEHOLD_1_181',
#  'HOUSEHOLD_1_514',
#  'FOODS_3_226',
#  'FOODS_1_012',
#  'FOODS_2_126',
#  'FOODS_3_033',
#  'FOODS_3_691',
#  'FOODS_3_539',
#  'FOODS_1_146',
#  'HOUSEHOLD_2_049',
#  'FOODS_2_043',
#  'HOUSEHOLD_2_341',
#  'HOUSEHOLD_1_066',
#  'HOUSEHOLD_1_478',
#  'FOODS_3_521',
#  'HOUSEHOLD_2_445',
#  'HOUSEHOLD_1_521',
#  'HOUSEHOLD_1_035',
#  'FOODS_3_205',
#  'FOODS_2_312',
#  'HOUSEHOLD_1_227',
#  'HOUSEHOLD_2_331',
#  'FOODS_1_055',
#  'HOUSEHOLD_1_248',
#  'FOODS_2_188',
#  'FOODS_3_542',
#  'FOODS_1_032',
#  'HOUSEHOLD_1_071',
#  'HOUSEHOLD_1_038',
#  'FOODS_1_052',
#  'FOODS_3_772',
#  'HOUSEHOLD_1_182',
#  'HOUSEHOLD_2_449',
#  'FOODS_2_217',
#  'FOODS_2_377',
#  'FOODS_1_162',
#  'FOODS_2_138',
#  'HOUSEHOLD_2_391',
#  'FOODS_3_100',
#  'HOUSEHOLD_1_067',
#  'FOODS_3_084',
#  'FOODS_3_626']

# %%
df_manufacture_info.head(5)
# Out:
#           ItemId  ManufactureLeadTime  ManufactureRate  UnitMaterialCost  \
# 0  HOBBIES_1_317                    2            20.40            274.29
# 1  HOBBIES_2_143                    1            30.66             22.06
# 2  HOBBIES_1_069                    5            17.57            279.38
# 3  HOBBIES_1_366                    5            17.73            252.67
# 4  HOBBIES_1_017                    5            29.96           3427.17
#
#    UnitManufactureCost WarehouseId  output_lot_per_cycle
# 0                40.13  PLANT_WH_0                 40.80
# 1                14.70  PLANT_WH_0                 30.66
# 2               262.09  PLANT_WH_0                 87.85
# 3               354.83  PLANT_WH_0                 88.65
# 4              1018.65  PLANT_WH_0                149.80

# %%
plant_0 = df_manufacture_info[df_manufacture_info['WarehouseId'] == 'PLANT_WH_0']['ItemId'].unique()
plant_0.shape
# Out:
# (40,)

# %%
plant_1 = df_manufacture_info[df_manufacture_info['WarehouseId'] == 'PLANT_WH_1']['ItemId'].unique()
plant_1.shape
# Out:
# (43,)

# %%
df_bom.head(5)
# Out:
#           ItemId ComponentItemId  ComponentQuantity
# 0  HOBBIES_1_317        COMP_758                  7
# 1  HOBBIES_1_317       COMP_1112                  5
# 2  HOBBIES_1_317       COMP_1965                  9
# 3  HOBBIES_1_317       COMP_1202                  6
# 4  HOBBIES_1_317         COMP_99                  3

# %%
comp_plant_0 = df_bom[df_bom['ItemId'].isin(plant_0)]['ComponentItemId'].unique()
print(comp_plant_0.shape)
comp_plant_0
# Out:
# (1498,)
# array(['COMP_758', 'COMP_1112', 'COMP_1965', ..., 'COMP_1698', 'COMP_342',
#        'COMP_358'], dtype=object)

# %%
comp_plant_1 = df_bom[df_bom['ItemId'].isin(plant_1)]['ComponentItemId'].unique()
print(comp_plant_1.shape)
comp_plant_1
# Out:
# (1642,)
# array(['COMP_195', 'COMP_1327', 'COMP_2025', ..., 'COMP_1661', 'COMP_537',
#        'COMP_1692'], dtype=object)

# %% [markdown]
# ### Generate config

# %%
config_topology = ""

for downstream, group1 in df_route.groupby("EndingLocationId"):
    assert downstream in facility_info
    
    config_topology += f"    {downstream}:\n"

    if 'STRG' not in downstream:
        for sku_name in facility_info[downstream]["skus"].keys():    
            config_topology += f"      {sku_name}:\n"

            for upstream, group2 in group1.groupby("StartingLocationId"):
                config_topology += f"        {upstream}:\n"

                for vehicle_type, vlt, cost in zip(
                    group2["RouteId"].to_numpy(),
                    group2["Duration"].to_numpy(),
                    group2["TransportationCost"].to_numpy(),
                ):
                    config_topology += (
                        f"          {vehicle_type}:\n"
                        f"            vlt: {vlt}\n"
                        f"            cost: {cost}\n"
                    )
    
    else:
        for sku_set, plant_name in zip([plant_0, plant_1], ['PLANT_WH_0', 'PLANT_WH_1']):
            group2 = group1[group1["StartingLocationId"] == plant_name]
            
            for sku_name in sku_set:    
                config_topology += f"      {sku_name}:\n"
                config_topology += f"        {plant_name}:\n"

                for vehicle_type, vlt, cost in zip(
                    group2["RouteId"].to_numpy(),
                    group2["Duration"].to_numpy(),
                    group2["TransportationCost"].to_numpy(),
                ):
                    config_topology += (
                        f"          {vehicle_type}:\n"
                        f"            vlt: {vlt}\n"
                        f"            cost: {cost}\n"
                    )
        
        for sku_name in products_from_vendor:  
            config_topology += (
                f"      {sku_name}:\n"
                f"        Super_Vendor:\n"
                f"          ROUTE_V:\n"
                f"            vlt: 1\n"
                f"            cost: 0\n"
            )

for downstream, comp_set in zip(['PLANT_WH_0', 'PLANT_WH_1'], [comp_plant_0, comp_plant_1]):
    config_topology += f"    {downstream}:\n"
    for sku_name in comp_set:
        config_topology += (
            f"      {sku_name}:\n"
            f"        Super_Vendor:\n"
            f"          ROUTE_V:\n"
            f"            vlt: 1\n"
            f"            cost: 0\n"
        )

# %%
print(config_topology[:835])
# Out:
#     CA_1:
#       HOBBIES_1_003:
#         CA_2:
#           ROUTE_45:
#             vlt: 6
#             cost: 0.22
#           ROUTE_171:
#             vlt: 5
#             cost: 0.39
#         CA_3:
#           ROUTE_54:
#             vlt: 5
#             cost: 0.47
#           ROUTE_180:
#             vlt: 5
#             cost: 0.44
#         CA_4:
#           ROUTE_63:
#             vlt: 6
#             cost: 0.3
#           ROUTE_189:
#             vlt: 4
#             cost: 0.61
#         STRG_CA_1:
#           ROUTE_6:
#             vlt: 4
#             cost: 0.62
#           ROUTE_132:
#             vlt: 4
#             cost: 0.6
#         STRG_TX_1:
#           ROUTE_16:
#             vlt: 3
#             cost: 0.84
#           ROUTE_142:
#             vlt: 2
#             cost: 1.0
#         STRG_WI_1:
#           ROUTE_26:
#             vlt: 2
#             cost: 0.89
#           ROUTE_152:

# %%
print(config_topology[-770:])
# Out:
#     COMP_1078:
#         Super_Vendor:
#           ROUTE_V:
#             vlt: 1
#             cost: 0
#       COMP_1270:
#         Super_Vendor:
#           ROUTE_V:
#             vlt: 1
#             cost: 0
#       COMP_927:
#         Super_Vendor:
#           ROUTE_V:
#             vlt: 1
#             cost: 0
#       COMP_536:
#         Super_Vendor:
#           ROUTE_V:
#             vlt: 1
#             cost: 0
#       COMP_763:
#         Super_Vendor:
#           ROUTE_V:
#             vlt: 1
#             cost: 0
#       COMP_1661:
#         Super_Vendor:
#           ROUTE_V:
#             vlt: 1
#             cost: 0
#       COMP_537:
#         Super_Vendor:
#           ROUTE_V:
#             vlt: 1
#             cost: 0
#       COMP_1692:
#         Super_Vendor:
#           ROUTE_V:
#             vlt: 1
#             cost: 0

# %% [markdown]
# ## Convert facility info to string

# %%
def get_vendor_string():
    config = (
        f"    - name: Super_Vendor\n"
        f"      definition_ref: SuperVendor\n"
        f"      skus:\n"
    )
    
    vendor_skus = df_item[~df_item["VendorId"].isnull()]["ItemId"].unique()
    for sku_name in vendor_skus:
        config += (
            f"        {sku_name}:\n"
            f"          price: 0.0\n"
            f"          init_stock: 10000\n"  # TODO: replace with another value, or set default value for it.
            
        )
    
    config += (
        f"      children:\n"
        f"        storage:\n"
        f"          config:\n"
        f"            capacity:\n"
        f"            unit_storage_cost: 0\n"
        f"        distribution:\n"
        f"          config:\n"
        f"            ROUTE_V:\n"
        f"              number:\n"
        f"      config:\n"
        f"        unit_order_cost: 0\n"
        f"        unit_delay_order_penalty: 0\n"
        f"\n"
    )

    return config

# %%
def convert_facility_info_to_string(name, info):
    config = (
        f"    - name: {name}\n"
        f"      definition_ref: {info['ref']}\n"
        f"      skus:\n"
    )

    for sku_name, sku_info in info["skus"].items():
        config += (
            f"        {sku_name}:\n"
            f"          price: {sku_info['price']}\n"
            f"          init_stock: {sku_info['init_stock']}\n"
            f"          unit_storage_cost: {sku_info['unit_storage_cost']}\n"
            f"          has_consumer: True\n"
        )
        
        if "manufacture" in sku_info:
            config += (
                f"          has_manufacture: True\n"
                f"          unit_product_cost: {sku_info['manufacture']['unit_cost']}\n"
                f"          max_manufacture_rate: {sku_info['manufacture']['max_rate']}\n"
                f"          manufacture_leading_time: {sku_info['manufacture']['leading_time']}\n"
            )
        
        if "seller" in sku_info:
            config += (
                f"          has_seller: True\n"
                f"          sale_gamma: {sku_info['seller']['gamma']}\n"
                f"          backlog_ratio: 0.0\n"
            )

    config += (
        f"      children:\n"
        f"        storage:\n"
        f"          config:\n"
        f"            capacity: {info['storage_capacity']}\n"
    )
    
    if "distribution" in info:
        # TODO: add infinite support
        config += (
            f"        distribution:\n"
            f"          config:\n"
        )
        for vehicle in info["distribution"]:
            config += f"            {vehicle[0]}:\n"
            if np.isnan(vehicle[1]):
                config += f"              number:\n"
            else:
                config += f"              number: {int(vehicle[1])}\n"

    config += (
        f"      config:\n"
        f"        unit_order_cost: {info['unit_order_cost']}\n"
        f"        unit_delay_order_penalty: 0\n"  # Notes: use 0 delay order penalty
    )
    if info['ref'] == "StoreFacility":
        config += (
            f"        file_path: {info['sales_path']}\n"
        )
    
    config += "\n"
    
    return config

# %%
config_facilities = get_vendor_string()

for facility_name, info in facility_info.items():
    if info['ref'] == "PlantFacility":
        config_facilities += convert_facility_info_to_string(facility_name, info)

for facility_name, info in facility_info.items():
    if info['ref'] == "WarehouseFacility":
        config_facilities += convert_facility_info_to_string(facility_name, info)

for facility_name, info in facility_info.items():
    if info['ref'] == "StoreFacility":
        config_facilities += convert_facility_info_to_string(facility_name, info)

# %% [markdown]
# ## Dump to config.yml file

# %%
config = f"""
facility_definitions:

  SuperVendor:
    class: "SupplierFacility"
    datamodel: "FacilityDataModel"
    children:
      storage:
        class: "SuperStorageUnit"
      distribution:
        class: "DistributionUnit"
    products:
      class: "ProductUnit"

  PlantFacility:
    class: "SupplierFacility"
    datamodel: "FacilityDataModel"
    children:
      storage:
        class: "StorageUnit"
      distribution:
        class: "DistributionUnit"
    products:
      class: "ProductUnit"
      config:
        manufacture:
          class: "ManufactureUnit"
        consumer:
          class: "ConsumerUnit"

  WarehouseFacility:
    class: "WarehouseFacility"
    children:
      storage:
        class: "StorageUnit"
      distribution:
        class: "DistributionUnit"
    products:
      class: "ProductUnit"
      config:
        consumer:
          class: "ConsumerUnit"

  StoreFacility:
    class: "OuterRetailerFacility"
    datamodel: "FacilityDataModel"
    children:
      storage:
        class: "StorageUnit"
      distribution:
        class: "DistributionUnit"
    products:
      class: "StoreProductUnit"
      config:
        consumer:
          class: "ConsumerUnit"
        seller:
          class: "OuterSellerUnit"
          config:
            sale_hist_len: 14
    config:
      dynamics_sampler_type: processed_price_demand
      sku_column: "ItemId" # SKU column name
      price_column: "Price" # Price column name
      demand_column: "Sales" # Sales column name
      datetime_column: "Date" # Datetime column name

world:
  skus:
{config_sku_meta}

  facilities:
{config_facilities}

  topology:
{config_topology}

settings:
  pending_order_len: 4
  start_date_time: "{start_date}"
"""

# %%
with open(os.path.join(cfg_dir, "config.yml"), "w") as fout:
    fout.write(config)
