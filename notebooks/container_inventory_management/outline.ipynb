# %% [markdown]
# # Outline
# * [Interact with simulator](./interact_with_simulator.ipynb)
#     * Get environment summary
#     * Step function (Gym-like), trigger simulator run
#     * Decision event, generated by simulator, consumed by agent, provides agent action scope
#     * Action, generated by agent, consumed by simulator, provides simulator execution action
#     * Snapshot list, generated by simulator, consumed by agent, provides space-time information of environment
#     * Get environment performance metrics
# * [Implement Vanilla RL agent](./implement_rl_agent.ipynb)
#     * State shpaing
#     * Action shaping
#     * Reward shaping
#     * Choose RL algorithm
